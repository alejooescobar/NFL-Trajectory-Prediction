000000000002, 7.38, 88.46, 4.8700000000000045, -4.59], [6.760000000000005, -2.75, 7.54, 88.46, 4.8700000000000045, -4.59], [7.510000000000005, -2.8900000000000006, 7.67, 87.76, 4.8700000000000045, -4.59], [8.269999999999996, -3.0199999999999996, 7.81, 87.76, 4.8700000000000045, -4.59], [9.049999999999997, -3.1400000000000006, 7.92, 92.38, 4.8700000000000045, -4.59], [9.840000000000003, -3.2600000000000016, 8.01, 95.7, 4.8700000000000045, -4.59], [10.629999999999995, -3.3900000000000006, 8.08, 99.37, 4.8700000000000045, -4.59], [11.430000000000007, -3.530000000000001, 8.1, 106.64, 4.8700000000000045, -4.59], [12.239999999999995, -3.700000000000003, 8.26, 126.4, 4.8700000000000045, -4.59], [13.040000000000006, -3.900000000000002, 8.21, 139.5, 4.8700000000000045, -4.59], [13.829999999999998, -4.140000000000001, 8.23, 148.47, 4.8700000000000045, -4.59], [14.599999999999994, -4.420000000000002, 8.2, 153.73, 4.8700000000000045, -4.59], [15.36, -4.740000000000002, 8.17, 163.52, 4.8700000000000045, -4.59], [16.099999999999994, -5.080000000000002, 8.05, 166.95, 4.8700000000000045, -4.59], [16.799999999999997, -5.48, 7.99, 186.45, 4.8700000000000045, -4.59]]

ex_o_1 = [[x[0],x[1],x[2],x[3],1.0,0] for x in ex_o_1]
ex_o_2 = [[x[0],x[1],x[2],x[3],1.0,0] for x in ex_o_2]
ex_o_3 = [[x[0],x[1],x[2],x[3],1.0,0] for x in ex_o_3]
ex_o_4 = [[x[0],x[1],x[2],x[3],1.0,0] for x in ex_o_4]

ex_d_1 = [[x[0]+1,x[1],x[2],x[3]] for x in ex_o_1]
ex_d_2 = [[x[0]+1,x[1],x[2],x[3]] for x in ex_o_2]
ex_d_3 = [[x[0]+1,x[1],x[2],x[3]] for x in ex_o_3]
ex_d_4 = [[x[0]+1,x[1],x[2],x[3]] for x in ex_o_4]


original_sequence = [ex_o_1,ex_o_2,ex_o_3,ex_o_4]
ex_seq_o = [ex_o_1,ex_o_2,ex_o_3,ex_o_4]
ex_seq_d = [ex_d_1,ex_d_2,ex_d_3,ex_d_4]
for seq in original_sequence:
    num = 1000
    for i in range(num):
        ex_o = [[x[0]+((x[0]/num)*i),x[1]+((x[1]/num)*i),x[2],x[3],1.0,0] for x in seq]
        ex_d = [[x[0]+1,x[1],x[2],x[3]] for x in ex_o] 
        ex_seq_o.append(ex_o)
        ex_seq_d.append(ex_d)
        ex_o = [[x[0]-((x[0]/num)*i),x[1]-((x[1]/num)*i),x[2],x[3],1.0,0] for x in seq]
        ex_d = [[x[0]+1,x[1],x[2],x[3]] for x in ex_o] 
        ex_seq_o.append(ex_o)
        ex_seq_d.append(ex_d)

# %%
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

padding_value = [-1.0 for i in range(len([ex_seq_o[0][0]]))]
padded_o_seq = tf.keras.preprocessing.sequence.pad_sequences(ex_seq_o,padding='post', value=padding_value, dtype='float32',maxlen = 90)
#print(padded_o_seq[0])
#padded_expanded_seq = tf.expand_dims(padded_o_seq, -1)
masking_layer = tf.keras.layers.Masking(mask_value=-1)
masked_o_seq = masking_layer(padded_o_seq)

padding_value = [-1.0 for i in range(len([ex_seq_d[0][0]]))]
padded_d_seq = tf.keras.preprocessing.sequence.pad_sequences(ex_seq_d,padding='post', value=padding_value, dtype='float32',maxlen = 90)
#print(padded_d_seq[0])
#padded_expanded_seq = tf.expand_dims(padded_d_seq, -1)
masking_layer = tf.keras.layers.Masking(mask_value=-1)
masked_d_seq = masking_layer(padded_d_seq)
#print(masked_d_seq[0])

# %%
import matplotlib.pyplot as plt
max_length = len(ex_seq_o)
input_index = 0
while True:
    input_index = int(input(f"Enter an integer between 0 and {max_length} to compare sequence prediction vs actual"))
    o_sequence = ex_seq_o[input_index]
    #print(f"Input Offensive Sequence: {o_sequence[0]},{o_sequence[1]},{o_sequence[2]}")
    d_sequence = ex_seq_d[input_index]

    offensive_sequence_x = [x[0] for x in o_sequence]
    offensive_sequence_y = [x[1] for x in o_sequence]
    defensive_sequence_x = [x[0] for x in d_sequence]
    defensive_sequence_y = [x[1] for x in d_sequence]

    #print("\n\n")
    print(o_sequence[0][4])
    print(o_sequence[0][5])
    print(d_sequence[0][0])
    print(d_sequence[0][1])

    #print("\n\n")
    #print(predicted_sequence_y)


    #print(f"Expected Sequence: {expected_sequence}\n\n")
    #print(f"Predicted Sequence: {predicted_sequence}\n\n")

    plt.scatter(offensive_sequence_x,offensive_sequence_y,color = "b",label="Offensive",s=10)
    plt.scatter(defensive_sequence_x,defensive_sequence_y,color = "r",label="Defensive",s=10)
    plt.scatter(defensive_sequence_x[0],defensive_sequence_y[0],color="r",s=30,marker='*')
    plt.scatter(offensive_sequence_x[0],offensive_sequence_x[0],color="b",s=30,marker='*')


    #plt.ylim([-15, 15])
    #plt.xlim([-15, 15])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [171], line 5
#       3 input_index = 0
#       4 while True:
# ----> 5     input_index = int(input(f"Enter an integer between 0 and {max_length} to compare sequence prediction vs actual"))
#       6     o_sequence = ex_seq_o[input_index]
#       7     #print(f"Input Offensive Sequence: {o_sequence[0]},{o_sequence[1]},{o_sequence[2]}")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
num_sequences = len(padded_o_seq)
num_train_sequences = int(num_sequences * 0.7)
dataset = tf.data.Dataset.from_tensor_slices((masked_o_seq,masked_d_seq))

# Shuffle the dataset
buffer_size = num_sequences
dataset = dataset.shuffle(buffer_size)

train_dataset = dataset.take(num_train_sequences)
test_dataset = dataset.skip(num_train_sequences)
#test_dataset_sample = test_dataset.take(1)
#print(list(test_dataset_sample))
batch_size = 32
train_dataset_batched = train_dataset.batch(batch_size)
test_dataset_batched = test_dataset.batch(batch_size)

# %%
input_shape = (batch_size, 90,6)
output_shape = len(ex_seq_d[0][0])

#masking_layer = tf.keras.layers.Masking(mask_value=-1)

model = tf.keras.Sequential([
  #masking_layer,
  tf.keras.layers.BatchNormalization(),
  tf.keras.layers.LSTM(90, input_shape=input_shape, return_sequences=True),
  #tf.keras.layers.Dense(38),
  tf.keras.layers.Dense(output_shape)
])

model.compile(optimizer='adam', loss='mae')

model.fit(train_dataset_batched, epochs=50)
loss = model.evaluate(test_dataset_batched)
print("Loss on test dataset: ", loss)
# Out:
# Epoch 1/50
# 176/176 [==============================] - 6s 26ms/step - loss: 10.4101
# Epoch 2/50
# 176/176 [==============================] - 5s 27ms/step - loss: 8.7777
# Epoch 3/50
# 176/176 [==============================] - 5s 27ms/step - loss: 7.3999
# Epoch 4/50
# 176/176 [==============================] - 5s 27ms/step - loss: 6.1868
# Epoch 5/50
# 176/176 [==============================] - 5s 27ms/step - loss: 4.9852
# Epoch 6/50
# 176/176 [==============================] - 5s 27ms/step - loss: 4.1346
# Epoch 7/50
# 176/176 [==============================] - 5s 27ms/step - loss: 3.6320
# Epoch 8/50
# 176/176 [==============================] - 5s 27ms/step - loss: 3.3075
# Epoch 9/50
# 176/176 [==============================] - 5s 29ms/step - loss: 3.0402
# Epoch 10/50
# 176/176 [==============================] - 5s 28ms/step - loss: 2.8777
# Epoch 11/50
# 176/176 [==============================] - 5s 27ms/step - loss: 2.6676
# Epoch 12/50
# ...

# %%
import matplotlib.pyplot as plt
max_length = len(ex_seq_o)
input_index = 0
while True:
    input_index = int(input(f"Enter an integer between 0 and {max_length} to compare sequence prediction vs actual"))
    o_sequence = ex_seq_o[input_index]
    #print(f"Input Offensive Sequence: {o_sequence[0]},{o_sequence[1]},{o_sequence[2]}")
    expected_sequence = ex_seq_d[input_index]
    print(len(expected_sequence))
    predict_dataset = tf.data.Dataset.from_tensor_slices(([o_sequence], [expected_sequence]))
    predict_dataset_batched = predict_dataset.batch(1)

    #input_sequence = np.expand_dims(input_sequence,axis=(0,1))
    predicted_sequence = model.predict(predict_dataset_batched)
    predicted_sequence = predicted_sequence[0]
    #print(f"Predicted Sequences: {predicted_sequence[0]},{predicted_sequence[1]},{predicted_sequence[2]}")

    predicted_sequence_x = [x[0] for x in predicted_sequence ]
    predicted_sequence_y = [x[1] for x in predicted_sequence]
    expected_sequence_x = [x[0] for x in expected_sequence ]
    expected_sequence_y = [x[1] for x in expected_sequence ]
    offensive_sequence_x = [x[0] for x in o_sequence]
    offensive_sequence_y = [x[1] for x in o_sequence]

    #print("\n\n")
    #print(o_sequence)
    #print("\n\n")
    #print(predicted_sequence_y)


    #print(f"Expected Sequence: {expected_sequence}\n\n")
    #print(f"Predicted Sequence: {predicted_sequence}\n\n")

    plt.scatter(offensive_sequence_x,offensive_sequence_y,color = "g",label="Offensive",s=10)
    plt.scatter(predicted_sequence_x,predicted_sequence_y,color = "r",label="Predicted",s=10)
    plt.scatter(expected_sequence_x,expected_sequence_y,color = "b",label="Expected",s=10)
    plt.scatter(predicted_sequence_x[0],predicted_sequence_y[0],color="r",s=30,marker='*')
    plt.scatter(expected_sequence_x[0],expected_sequence_y[0],color="b",s=30,marker='*')
    plt.scatter(offensive_sequence_x[0],offensive_sequence_x[0],color="g",s=30,marker='*')


    #plt.ylim([-15, 15])
    #plt.xlim([-15, 15])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.show()
# Out:
# 38
# 1/1 [==============================] - 0s 483ms/step
# 38
# 1/1 [==============================] - 0s 11ms/step
# 44
# 1/1 [==============================] - 0s 287ms/step
# 32
# 1/1 [==============================] - 0s 28ms/step
# 38
# 1/1 [==============================] - 0s 9ms/step
# 38
# 1/1 [==============================] - 0s 9ms/step
# 32
# 1/1 [==============================] - 0s 9ms/step
# 38
# 1/1 [==============================] - 0s 9ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [182], line 5
#       3 input_index = 0
#       4 while True:
# ----> 5     input_index = int(input(f"Enter an integer between 0 and {max_length} to compare sequence prediction vs actual"))
#       6     o_sequence = ex_seq_o[input_index]
#       7     #print(f"Input Offensive Sequence: {o_sequence[0]},{o_sequence[1]},{o_sequence[2]}")
#
# ...

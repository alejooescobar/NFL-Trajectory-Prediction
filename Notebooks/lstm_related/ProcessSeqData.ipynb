# %% [markdown]
# ### Installing Required Libraries

# %%
# %pip install numpy pandas matplotlib seaborn ipython jupyterlab Pillow pyscreenshot tensorflow scikit-learn
# Out:
# Requirement already satisfied: numpy in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (1.23.4)
# Requirement already satisfied: pandas in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (1.5.1)
# Requirement already satisfied: matplotlib in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (3.6.2)
# Requirement already satisfied: seaborn in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (0.12.1)
# Requirement already satisfied: ipython in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (8.6.0)
# Requirement already satisfied: jupyterlab in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (3.5.0)
# Requirement already satisfied: Pillow in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (9.3.0)
# Requirement already satisfied: pyscreenshot in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (3.0)
# Requirement already satisfied: tensorflow in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (2.10.0)
# Requirement already satisfied: scikit-learn in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (1.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas) (2022.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (21.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: matplotlib-inline in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from ipython) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from ipython) (0.7.5)
# Requirement already satisfied: backcall in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from ipython) (0.2.0)
# Requirement already satisfied: stack-data in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from ipython) (0.6.0)
# Requirement already satisfied: colorama in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from ipython) (0.4.6)
# Requirement already satisfied: jedi>=0.16 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from ipython) (0.18.1)
# Requirement already satisfied: decorator in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from ipython) (5.1.1)
# Requirement already satisfied: traitlets>=5 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from ipython) (5.5.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from ipython) (3.0.32)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from ipython) (2.13.0)
# Requirement already satisfied: jupyter-core in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyterlab) (5.0.0)
# Requirement already satisfied: jupyterlab-server~=2.10 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyterlab) (2.16.3)
# Requirement already satisfied: jinja2>=2.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyterlab) (3.1.2)
# Requirement already satisfied: notebook<7 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyterlab) (6.5.2)
# Requirement already satisfied: tomli in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyterlab) (2.0.1)
# Requirement already satisfied: jupyter-server<3,>=1.16.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyterlab) (1.23.1)
# Requirement already satisfied: nbclassic in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyterlab) (0.4.8)
# Requirement already satisfied: tornado>=6.1.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyterlab) (6.2)
# Requirement already satisfied: EasyProcess in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pyscreenshot) (1.1)
# Requirement already satisfied: mss in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pyscreenshot) (7.0.1)
# Requirement already satisfied: entrypoint2 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pyscreenshot) (1.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: setuptools in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (67.6.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (1.50.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (4.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (1.3.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (22.10.26)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (0.27.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (14.0.6)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from scikit-learn) (1.9.3)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from astunparse>=1.6.0->tensorflow) (0.38.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jedi>=0.16->ipython) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jinja2>=2.1->jupyterlab) (2.1.1)
# Requirement already satisfied: Send2Trash in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (1.8.0)
# Requirement already satisfied: prometheus-client in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (0.15.0)
# Requirement already satisfied: pywinpty in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (2.0.9)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (0.17.0)
# Requirement already satisfied: argon2-cffi in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (21.3.0)
# Requirement already satisfied: websocket-client in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (1.4.2)
# Requirement already satisfied: pyzmq>=17 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (24.0.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (3.6.2)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (7.2.4)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (7.4.5)
# Requirement already satisfied: nbformat>=5.2.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (5.7.0)
# Requirement already satisfied: platformdirs in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyter-core->jupyterlab) (2.5.3)
# Requirement already satisfied: pywin32>=1.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyter-core->jupyterlab) (305)
# Requirement already satisfied: jsonschema>=3.0.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyterlab-server~=2.10->jupyterlab) (4.17.0)
# Requirement already satisfied: importlib-metadata>=4.8.3 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyterlab-server~=2.10->jupyterlab) (5.0.0)
# Requirement already satisfied: babel in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyterlab-server~=2.10->jupyterlab) (2.11.0)
# Requirement already satisfied: json5 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyterlab-server~=2.10->jupyterlab) (0.9.10)
# Requirement already satisfied: requests in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyterlab-server~=2.10->jupyterlab) (2.28.1)
# Requirement already satisfied: ipython-genutils in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from notebook<7->jupyterlab) (0.2.0)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from notebook<7->jupyterlab) (1.5.6)
# Requirement already satisfied: ipykernel in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from notebook<7->jupyterlab) (6.17.1)
# Requirement already satisfied: notebook-shim>=0.1.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nbclassic->jupyterlab) (0.2.2)
# Requirement already satisfied: wcwidth in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython) (0.2.5)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.14.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.2.2)
# Requirement already satisfied: pure-eval in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from stack-data->ipython) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from stack-data->ipython) (2.1.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from stack-data->ipython) (1.2.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab) (1.3.0)
# Requirement already satisfied: idna>=2.8 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab) (3.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (1.3.1)
# Requirement already satisfied: zipp>=0.5 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from importlib-metadata>=4.8.3->jupyterlab-server~=2.10->jupyterlab) (3.10.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab) (0.19.2)
# Requirement already satisfied: entrypoints in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from jupyter-client>=6.1.12->jupyter-server<3,>=1.16.0->jupyterlab) (0.4)
# Requirement already satisfied: tinycss2 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (1.2.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (2.0.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.2.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (4.11.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (1.5.0)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.7.0)
# Requirement already satisfied: bleach in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (5.0.1)
# Requirement already satisfied: defusedxml in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.7.1)
# Requirement already satisfied: fastjsonschema in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from nbformat>=5.2.0->jupyter-server<3,>=1.16.0->jupyterlab) (2.16.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->jupyterlab-server~=2.10->jupyterlab) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->jupyterlab-server~=2.10->jupyterlab) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests->jupyterlab-server~=2.10->jupyterlab) (1.26.12)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab) (21.2.0)
# Requirement already satisfied: psutil in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from ipykernel->notebook<7->jupyterlab) (5.9.4)
# Requirement already satisfied: debugpy>=1.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from ipykernel->notebook<7->jupyterlab) (1.6.3)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.2)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (2.3.2.post1)
# Requirement already satisfied: webencodings in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\alejo\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab) (2.21)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: C:\Users\Alejo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from datetime import datetime
import math
from collections import defaultdict

# %% [markdown]
# ### Processing NFL Datasets

# %%
game_data = pd.read_csv('../../NFLData/games.csv')
pff_scouting_data = pd.read_csv('../../NFLData/pffScoutingData.csv')
player_data = pd.read_csv('../../NFLData/players.csv')
play_data = pd.read_csv('../../NFLData/plays.csv')
tracking_w1_data_original = pd.read_csv('../../NFLData/week1.csv')
tracking_w2_data_original = pd.read_csv('../../NFLData/week2.csv')
tracking_w3_data_original = pd.read_csv('../../NFLData/week3.csv')
tracking_w4_data_original = pd.read_csv('../../NFLData/week4.csv')
tracking_w5_data_original = pd.read_csv('../../NFLData/week5.csv')
tracking_w6_data_original = pd.read_csv('../../NFLData/week6.csv')
tracking_w7_data_original = pd.read_csv('../../NFLData/week7.csv')
tracking_w8_data_original = pd.read_csv('../../NFLData/week8.csv')
tracking_w1_data_original = pd.concat([tracking_w1_data_original,tracking_w2_data_original,tracking_w3_data_original,tracking_w4_data_original,tracking_w5_data_original,tracking_w6_data_original,tracking_w7_data_original,tracking_w8_data_original])

# %%
print(tracking_w1_data_original.shape[0])
print(play_data.shape[0])
print(player_data.shape[0])
print(game_data.shape[0])
# Out:
# 8314178
# 8557
# 1679
# 122

# %% [markdown]
# ### 2018 Big Data Bowl Data

# %%
game_2018_data = pd.read_csv('../../NFLData/2018games.csv')
player_2018_data = pd.read_csv('../../NFLData/2018players.csv')
play_2018_data = pd.read_csv('../../NFLData/2018plays.csv')
tracking_w1_data_2018 = pd.read_csv('../../NFLData/2018week1.csv')
tracking_w2_data_2018 = pd.read_csv('../../NFLData/2018week2.csv')
tracking_w3_data_2018 = pd.read_csv('../../NFLData/2018week3.csv')
tracking_w4_data_2018 = pd.read_csv('../../NFLData/2018week4.csv')
tracking_w5_data_2018 = pd.read_csv('../../NFLData/2018week5.csv')
tracking_w6_data_2018 = pd.read_csv('../../NFLData/2018week6.csv')
tracking_w7_data_2018 = pd.read_csv('../../NFLData/2018week7.csv')
tracking_w8_data_2018 = pd.read_csv('../../NFLData/2018week8.csv')
tracking_w9_data_2018 = pd.read_csv('../../NFLData/2018week9.csv')
tracking_w10_data_2018 = pd.read_csv('../../NFLData/2018week10.csv')
tracking_w11_data_2018 = pd.read_csv('../../NFLData/2018week11.csv')
tracking_w12_data_2018 = pd.read_csv('../../NFLData/2018week12.csv')
tracking_w13_data_2018 = pd.read_csv('../../NFLData/2018week13.csv')
tracking_w14_data_2018 = pd.read_csv('../../NFLData/2018week14.csv')
tracking_w15_data_2018 = pd.read_csv('../../NFLData/2018week15.csv')
tracking_w16_data_2018 = pd.read_csv('../../NFLData/2018week16.csv')
tracking_w17_data_2018 = pd.read_csv('../../NFLData/2018week17.csv')
tracking_2018_data = pd.concat([tracking_w1_data_2018,tracking_w2_data_2018,tracking_w3_data_2018,tracking_w4_data_2018,
                           tracking_w5_data_2018,tracking_w6_data_2018,tracking_w7_data_2018,tracking_w8_data_2018,
                           tracking_w9_data_2018,tracking_w10_data_2018,tracking_w11_data_2018,tracking_w12_data_2018,
                           tracking_w13_data_2018,tracking_w14_data_2018,tracking_w15_data_2018,tracking_w16_data_2018,
                           tracking_w17_data_2018])

# %%
print(tracking_2018_data.shape[0])
print(play_2018_data.shape[0])
print(player_2018_data.shape[0])
print(game_2018_data.shape[0])
# Out:
# 18309388
# 19239
# 1303
# 253

# %% [markdown]
# ### Code To Merge 2018 and 2021 Data

# %%
game_data.drop(columns=["season"],inplace=True) # Dropping unneeded column from 2023 dataset
player_2018_data.rename(columns={"position":"officialPosition"},inplace=True)
play_2018_data.rename(columns={"position":"officialPosition"},inplace=True) # renaming columns to allow concat
# Selecting the necessary columns from each play df
play_data = play_data[["gameId","playId","playDescription","quarter","down","yardsToGo","possessionTeam","yardlineSide",
                       "yardlineNumber","gameClock","preSnapHomeScore","preSnapVisitorScore","passResult",
                       "playResult","absoluteYardlineNumber","offenseFormation"]]
play_2018_data = play_2018_data[["gameId","playId","playDescription","quarter","down","yardsToGo","possessionTeam","yardlineSide",
                       "yardlineNumber","gameClock","preSnapHomeScore","preSnapVisitorScore","passResult",
                       "playResult","absoluteYardlineNumber","offenseFormation"]]
tracking_2018_data = tracking_2018_data[["gameId","playId","nflId","frameId","time","jerseyNumber","team","playDirection","x","y","s","a"
                                         ,"dis","o","dir","event"]]

# %%
display(game_data.head(5))
display(play_data.head(5))
display(player_data.head(5))
display(tracking_w1_data_original.head(5))
# Out:
#        gameId  week    gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr
# 0  2021090900     1  09/09/2021        20:20:00           TB             DAL
# 1  2021091200     1  09/12/2021        13:00:00          ATL             PHI
# 2  2021091201     1  09/12/2021        13:00:00          BUF             PIT
# 3  2021091202     1  09/12/2021        13:00:00          CAR             NYJ
# 4  2021091203     1  09/12/2021        13:00:00          CIN             MIN
#        gameId  playId                                    playDescription  \
# 0  2021090900      97  (13:33) (Shotgun) T.Brady pass incomplete deep...
# 1  2021090900     137  (13:18) (Shotgun) D.Prescott pass deep left to...
# 2  2021090900     187  (12:23) (Shotgun) D.Prescott pass short middle...
# 3  2021090900     282  (9:56) D.Prescott pass incomplete deep left to...
# 4  2021090900     349  (9:46) (Shotgun) D.Prescott pass incomplete sh...
#
#    quarter  down  yardsToGo possessionTeam yardlineSide  yardlineNumber  \
# 0        1     3          2             TB           TB              33
# 1        1     1         10            DAL          DAL               2
# 2        1     2          6            DAL          DAL              34
# 3        1     1         10            DAL           TB              39
# 4        1     3         15            DAL           TB              44
#
#   gameClock  preSnapHomeScore  preSnapVisitorScore passResult  playResult  \
# 0     13:33                 0                    0          I           0
# 1     13:18                 0                    0          C          28
# 2     12:23                 0                    0          C           5
# 3     09:56                 0                    0          I           0
# 4     09:46                 0                    0          I           0
#
#    absoluteYardlineNumber offenseFormation
# 0                    43.0          SHOTGUN
# 1                   108.0            EMPTY
# 2                    76.0          SHOTGUN
# 3                    49.0       SINGLEBACK
# 4                    54.0          SHOTGUN
#    nflId height  weight   birthDate collegeName officialPosition  \
# 0  25511    6-4     225  1977-08-03    Michigan               QB
# 1  28963    6-5     240  1982-03-02   Miami, O.               QB
# 2  29550    6-4     328  1982-01-22    Arkansas                T
# 3  29851    6-2     225  1983-12-02  California               QB
# 4  30078    6-2     228  1982-11-24     Harvard               QB
#
#           displayName
# 0           Tom Brady
# 1  Ben Roethlisberger
# 2        Jason Peters
# 3       Aaron Rodgers
# 4    Ryan Fitzpatrick
#        gameId  playId    nflId  frameId                     time  \
# 0  2021090900      97  25511.0        1  2021-09-10T00:26:31.100
# 1  2021090900      97  25511.0        2  2021-09-10T00:26:31.200
# 2  2021090900      97  25511.0        3  2021-09-10T00:26:31.300
# 3  2021090900      97  25511.0        4  2021-09-10T00:26:31.400
# 4  2021090900      97  25511.0        5  2021-09-10T00:26:31.500
#
#    jerseyNumber team playDirection      x      y     s     a   dis       o  \
# 0          12.0   TB         right  37.77  24.22  0.29  0.30  0.03  165.16
# 1          12.0   TB         right  37.78  24.22  0.23  0.11  0.02  164.33
# 2          12.0   TB         right  37.78  24.24  0.16  0.10  0.01  160.24
# 3          12.0   TB         right  37.73  24.25  0.15  0.24  0.06  152.13
# 4          12.0   TB         right  37.69  24.26  0.25  0.18  0.04  148.33
#
#       dir event
# 0   84.99  None
# 1   92.87  None
# 2   68.55  None
# 3  296.85  None
# 4  287.55  None

# %%
display(game_2018_data.head(5))
display(play_2018_data.head(5))
display(player_2018_data.head(5))
display(tracking_w1_data_2018.head(5))
# Out:
#        gameId    gameDate gameTimeEastern homeTeamAbbr visitorTeamAbbr  week
# 0  2018090600  09/06/2018        20:20:00          PHI             ATL     1
# 1  2018090901  09/09/2018        13:00:00          CLE             PIT     1
# 2  2018090902  09/09/2018        13:00:00          IND             CIN     1
# 3  2018090903  09/09/2018        13:00:00          MIA             TEN     1
# 4  2018090900  09/09/2018        13:00:00          BAL             BUF     1
#        gameId  playId                                    playDescription  \
# 0  2018090600      75  (15:00) M.Ryan pass short right to J.Jones pus...
# 1  2018090600     146  (13:10) M.Ryan pass incomplete short right to ...
# 2  2018090600     168  (13:05) (Shotgun) M.Ryan pass incomplete short...
# 3  2018090600     190  (13:01) (Shotgun) M.Ryan pass deep left to J.J...
# 4  2018090600     256  (10:59) (Shotgun) M.Ryan pass incomplete short...
#
#    quarter  down  yardsToGo possessionTeam yardlineSide  yardlineNumber  \
# 0        1     1         15            ATL          ATL              20
# 1        1     1         10            ATL          PHI              39
# 2        1     2         10            ATL          PHI              39
# 3        1     3         10            ATL          PHI              39
# 4        1     3          1            ATL          PHI               1
#
#   gameClock  preSnapHomeScore  preSnapVisitorScore passResult  playResult  \
# 0  15:00:00               0.0                  0.0          C          10
# 1  13:10:00               0.0                  0.0          I           0
# 2  13:05:00               0.0                  0.0          I           0
# 3  13:01:00               0.0                  0.0          C          33
# 4  10:59:00               0.0                  0.0          I           0
#
#    absoluteYardlineNumber offenseFormation
# 0                    90.0           I_FORM
# 1                    49.0       SINGLEBACK
# 2                    49.0          SHOTGUN
# 3                    49.0          SHOTGUN
# 4                    11.0          SHOTGUN
#      nflId height  weight   birthDate             collegeName  \
# 0  2539334     72     190  1990-09-10              Washington
# 1  2539653     70     186  1988-11-01  Southeastern Louisiana
# 2  2543850     69     186  1991-12-18                  Purdue
# 3  2555162     73     227  1994-11-04         Louisiana State
# 4  2555255     75     232  1993-07-01               Minnesota
#
#   officialPosition         displayName
# 0               CB     Desmond Trufant
# 1               CB       Robert Alford
# 2               SS       Ricardo Allen
# 3              MLB         Deion Jones
# 4              OLB  De'Vondre Campbell
#                        time      x      y     s     a   dis       o     dir  \
# 0  2018-09-07T01:07:14.599Z  91.73  26.67  0.00  0.01  0.02  289.57  240.93
# 1  2018-09-07T01:07:14.599Z  88.89  36.47  0.01  0.01  0.01  105.63   66.66
# 2  2018-09-07T01:07:14.599Z  91.35  44.16  0.02  0.03  0.01  290.45   16.86
# 3  2018-09-07T01:07:14.599Z  86.31  22.01  0.09  0.42  0.01   70.12  168.91
# 4  2018-09-07T01:07:14.599Z  90.78  36.15  0.00  0.00  0.00  257.61  193.97
#
#   event      nflId      displayName  jerseyNumber position  frameId  team  \
# 0  None      310.0        Matt Ryan           2.0       QB        1  away
# 1  None    79848.0  Malcolm Jenkins          27.0       SS        1  home
# 2  None  2495454.0      Julio Jones          11.0       WR        1  away
# 3  None  2495613.0     Corey Graham          24.0       FS        1  home
# 4  None  2533040.0     Mohamed Sanu          12.0       WR        1  away
#
#        gameId  playId playDirection  route
# 0  2018090600      75          left    NaN
# 1  2018090600      75          left    NaN
# 2  2018090600      75          left  HITCH
# 3  2018090600      75          left    NaN
# 4  2018090600      75          left  HITCH

# %% [markdown]
# ### Concatenate Dataframes

# %%
game_data = pd.concat([game_data,game_2018_data])
play_data = pd.concat([play_data,play_2018_data])
tracking_w1_data_original = pd.concat([tracking_w1_data_original,tracking_2018_data])
player_data = pd.concat([player_data,player_2018_data])

# %%
teams = game_data[["gameId","homeTeamAbbr","visitorTeamAbbr"]]
display(teams)
# Out:
#          gameId homeTeamAbbr visitorTeamAbbr
# 0    2021090900           TB             DAL
# 1    2021091200          ATL             PHI
# 2    2021091201          BUF             PIT
# 3    2021091202          CAR             NYJ
# 4    2021091203          CIN             MIN
# ..          ...          ...             ...
# 248  2018123013          DEN             LAC
# 249  2018123015          SEA             ARI
# 250  2018123014           LA              SF
# 251  2018122200          TEN             WAS
# 252  2018122201          LAC             BAL
#
# [375 rows x 3 columns]

# %% [markdown]
# ### Merge Tracking Data With Teams

# %%
tracking_w1_data_original = tracking_w1_data_original.merge(game_data,on="gameId",how="left")
display(tracking_w1_data_original)
# Out:
#               gameId  playId      nflId  frameId                      time  \
# 0         2021090900      97    25511.0        1   2021-09-10T00:26:31.100
# 1         2021090900      97    25511.0        2   2021-09-10T00:26:31.200
# 2         2021090900      97    25511.0        3   2021-09-10T00:26:31.300
# 3         2021090900      97    25511.0        4   2021-09-10T00:26:31.400
# 4         2021090900      97    25511.0        5   2021-09-10T00:26:31.500
# ...              ...     ...        ...      ...                       ...
# 26623561  2018123011    4261  2558942.0      102  2018-12-31T04:23:24.200Z
# 26623562  2018123011    4261  2558976.0      102  2018-12-31T04:23:24.200Z
# 26623563  2018123011    4261  2560789.0      102  2018-12-31T04:23:24.200Z
# 26623564  2018123011    4261  2561521.0      102  2018-12-31T04:23:24.200Z
# 26623565  2018123011    4261        NaN      102  2018-12-31T04:23:24.200Z
#
#           jerseyNumber      team playDirection       x      y  ...     a  \
# 0                 12.0        TB         right   37.77  24.22  ...  0.30
# 1                 12.0        TB         right   37.78  24.22  ...  0.11
# 2                 12.0        TB         right   37.78  24.24  ...  0.10
# 3                 12.0        TB         right   37.73  24.25  ...  0.24
# 4                 12.0        TB         right   37.69  24.26  ...  0.18
# ...                ...       ...           ...     ...    ...  ...   ...
# 26623561          86.0      home          left   95.77  11.20  ...  1.75
# 26623562          23.0      away          left  101.94  14.60  ...  2.24
# 26623563          53.0      away          left  102.68   0.94  ...  1.67
# 26623564          17.0      home          left  105.82   0.71  ...  3.53
# 26623565           NaN  football          left  101.33   0.91  ...  0.67
#
#            dis       o     dir  event week    gameDate gameTimeEastern  \
# 0         0.03  165.16   84.99   None    1  09/09/2021        20:20:00
# 1         0.02  164.33   92.87   None    1  09/09/2021        20:20:00
# 2         0.01  160.24   68.55   None    1  09/09/2021        20:20:00
# 3         0.06  152.13  296.85   None    1  09/09/2021        20:20:00
# 4         0.04  148.33  287.55   None    1  09/09/2021        20:20:00
# ...        ...     ...     ...    ...  ...         ...             ...
# 26623561  0.73  103.97  118.54   None   17  12/30/2018        20:20:00
# 26623562  0.57  139.23  119.97   None   17  12/30/2018        20:20:00
# 26623563  0.24  164.79  152.29   None   17  12/30/2018        20:20:00
# 26623564  0.25  284.72   93.44   None   17  12/30/2018        20:20:00
# 26623565  0.10     NaN     NaN   None   17  12/30/2018        20:20:00
#
#          homeTeamAbbr visitorTeamAbbr
# 0                  TB             DAL
# 1                  TB             DAL
# 2                  TB             DAL
# 3                  TB             DAL
# 4                  TB             DAL
# ...               ...             ...
# 26623561          TEN             IND
# 26623562          TEN             IND
# 26623563          TEN             IND
# 26623564          TEN             IND
# 26623565          TEN             IND
#
# [26623566 rows x 21 columns]

# %%
print(tracking_w1_data_original.shape[0])
print(play_data.shape[0])
print(player_data.shape[0])
print(game_data.shape[0])
# Out:
# 26623566
# 27796
# 2982
# 375

# %% [markdown]
# ### Displaying Nan Values In Pandas Dataframes

# %%
nan_values = game_data.isna().sum()
print("-- Game Data Nan Values --")
print(nan_values)

nan_values = pff_scouting_data.isna().sum()
print("-- PFF Scouting Data Nan Values --")
print(nan_values)

nan_values = player_data.isna().sum()
print("-- Player Data Nan Values --")
print(nan_values)

nan_values = play_data.isna().sum()
print("-- Play Data Nan Values --")
print(nan_values)
# Out:
# -- Game Data Nan Values --
# gameId             0
# season             0
# week               0
# gameDate           0
# gameTimeEastern    0
# homeTeamAbbr       0
# visitorTeamAbbr    0
# dtype: int64
# -- PFF Scouting Data Nan Values --
# gameId                         0
# playId                         0
# nflId                          0
# pff_role                       0
# pff_positionLinedUp            0
# pff_hit                    94127
# pff_hurry                  94127
# pff_sack                   94127
# pff_beatenByDefender      140167
# pff_hitAllowed            140167
# pff_hurryAllowed          140167
# pff_sackAllowed           140167
# pff_nflIdBlockedPlayer    141728
# pff_blockType             140350
# pff_backFieldBlock        140351
# dtype: int64
# -- Player Data Nan Values --
# nflId                 0
# height                0
# weight                0
# birthDate           232
# collegeName         224
# officialPosition      0
# displayName           0
# dtype: int64
# -- Play Data Nan Values --
# gameId                       0
# playId                       0
# playDescription              0
# quarter                      0
# down                         0
# yardsToGo                    0
# possessionTeam               0
# defensiveTeam                0
# yardlineSide               125
# yardlineNumber               0
# gameClock                    0
# preSnapHomeScore             0
# preSnapVisitorScore          0
# passResult                   0
# penaltyYards              7801
# prePenaltyPlayResult         0
# playResult                   0
# foulName1                 7821
# foulNFLId1                7821
# foulName2                 8527
# foulNFLId2                8527
# foulName3                 8556
# foulNFLId3                8556
# absoluteYardlineNumber       1
# offenseFormation             7
# personnelO                   1
# defendersInBox               7
# personnelD                   1
# dropBackType               528
# pff_playAction               0
# pff_passCoverage             0
# pff_passCoverageType         0
# dtype: int64

# %% [markdown]
# ### Displaying Nan Values In Tracking Dataframes

# %%
nan_values = tracking_w1_data_original.isna().sum()
print("-- Tracking Week 1 Data Nan Values --")
print(nan_values)

nan_values = tracking_w2_data_original.isna().sum()
print("-- Tracking Week 1 Data Nan Values --")
print(nan_values)

nan_values = tracking_w3_data_original.isna().sum()
print("-- Tracking Week 1 Data Nan Values --")
print(nan_values)

nan_values = tracking_w4_data_original.isna().sum()
print("-- Tracking Week 1 Data Nan Values --")
print(nan_values)

nan_values = tracking_w5_data_original.isna().sum()
print("-- Tracking Week 1 Data Nan Values --")
print(nan_values)

nan_values = tracking_w6_data_original.isna().sum()
print("-- Tracking Week 1 Data Nan Values --")
print(nan_values)

nan_values = tracking_w7_data_original.isna().sum()
print("-- Tracking Week 1 Data Nan Values --")
print(nan_values)

nan_values = tracking_w8_data_original.isna().sum()
print("-- Tracking Week 1 Data Nan Values --")
print(nan_values)
# Out:
# -- Tracking Week 1 Data Nan Values --
# gameId                0
# playId                0
# nflId            361486
# frameId               0
# time                  0
# jerseyNumber     361486
# team                  0
# playDirection         0
# x                     0
# y                     0
# s                     0
# a                     0
# dis                   0
# o                361486
# dir              361486
# event                 0
# dtype: int64
# -- Tracking Week 1 Data Nan Values --
# gameId               0
# playId               0
# nflId            45338
# frameId              0
# time                 0
# jerseyNumber     45338
# team                 0
# playDirection        0
# x                    0
# y                    0
# s                    0
# a                    0
# dis                  0
# o                45338
# dir              45338
# event                0
# dtype: int64
# -- Tracking Week 1 Data Nan Values --
# gameId               0
# playId               0
# nflId            48775
# frameId              0
# time                 0
# jerseyNumber     48775
# team                 0
# playDirection        0
# x                    0
# y                    0
# s                    0
# a                    0
# dis                  0
# o                48775
# dir              48775
# event                0
# dtype: int64
# -- Tracking Week 1 Data Nan Values --
# gameId               0
# playId               0
# nflId            46722
# frameId              0
# time                 0
# jerseyNumber     46722
# team                 0
# playDirection        0
# x                    0
# y                    0
# s                    0
# a                    0
# dis                  0
# o                46722
# dir              46722
# event                0
# dtype: int64
# -- Tracking Week 1 Data Nan Values --
# gameId               0
# playId               0
# nflId            47731
# frameId              0
# time                 0
# jerseyNumber     47731
# team                 0
# playDirection        0
# x                    0
# y                    0
# s                    0
# a                    0
# dis                  0
# o                47731
# dir              47731
# event                0
# dtype: int64
# -- Tracking Week 1 Data Nan Values --
# gameId               0
# playId               0
# nflId            42339
# frameId              0
# time                 0
# jerseyNumber     42339
# team                 0
# playDirection        0
# x                    0
# y                    0
# s                    0
# a                    0
# dis                  0
# o                42339
# dir              42339
# event                0
# dtype: int64
# -- Tracking Week 1 Data Nan Values --
# gameId               0
# playId               0
# nflId            39404
# frameId              0
# time                 0
# jerseyNumber     39404
# team                 0
# playDirection        0
# x                    0
# y                    0
# s                    0
# a                    0
# dis                  0
# o                39404
# dir              39404
# event                0
# dtype: int64
# -- Tracking Week 1 Data Nan Values --
# gameId               0
# playId               0
# nflId            42563
# frameId              0
# time                 0
# jerseyNumber     42563
# team                 0
# playDirection        0
# x                    0
# y                    0
# s                    0
# a                    0
# dis                  0
# o                42563
# dir              42563
# event                0
# dtype: int64

# %% [markdown]
# ### Displaying Game Data Format

# %%
print("-- Printing first 5 rows --\n\n")
display(game_data.head(5))
print("\n\n-- Printing Columns --\n\n")
print(game_data.columns)
# Out:
# -- Printing first 5 rows --
#        gameId  season  week    gameDate gameTimeEastern homeTeamAbbr  \
# 0  2021090900    2021     1  09/09/2021        20:20:00           TB
# 1  2021091200    2021     1  09/12/2021        13:00:00          ATL
# 2  2021091201    2021     1  09/12/2021        13:00:00          BUF
# 3  2021091202    2021     1  09/12/2021        13:00:00          CAR
# 4  2021091203    2021     1  09/12/2021        13:00:00          CIN
#
#   visitorTeamAbbr
# 0             DAL
# 1             PHI
# 2             PIT
# 3             NYJ
# 4             MIN
# -- Printing Columns --
#
#
# Index(['gameId', 'season', 'week', 'gameDate', 'gameTimeEastern',
#        'homeTeamAbbr', 'visitorTeamAbbr'],
#       dtype='object')

# %% [markdown]
# ### Displaying PFF Scouting Data Format

# %%
print("-- Printing first 5 rows --\n\n")
display(pff_scouting_data.head(5))
print("\n\n-- Printing Columns --\n\n")
print(pff_scouting_data.columns)
# Out:
# -- Printing first 5 rows --
#        gameId  playId  nflId    pff_role pff_positionLinedUp  pff_hit  \
# 0  2021090900      97  25511        Pass                  QB      NaN
# 1  2021090900      97  35481  Pass Route                TE-L      NaN
# 2  2021090900      97  35634  Pass Route                 LWR      NaN
# 3  2021090900      97  39985  Pass Route                HB-R      NaN
# 4  2021090900      97  40151  Pass Block                   C      NaN
#
#    pff_hurry  pff_sack  pff_beatenByDefender  pff_hitAllowed  \
# 0        NaN       NaN                   NaN             NaN
# 1        NaN       NaN                   NaN             NaN
# 2        NaN       NaN                   NaN             NaN
# 3        NaN       NaN                   NaN             NaN
# 4        NaN       NaN                   0.0             0.0
#
#    pff_hurryAllowed  pff_sackAllowed  pff_nflIdBlockedPlayer pff_blockType  \
# 0               NaN              NaN                     NaN           NaN
# 1               NaN              NaN                     NaN           NaN
# 2               NaN              NaN                     NaN           NaN
# 3               NaN              NaN                     NaN           NaN
# 4               0.0              0.0                 44955.0            SW
#
#    pff_backFieldBlock
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 0.0
# -- Printing Columns --
#
#
# Index(['gameId', 'playId', 'nflId', 'pff_role', 'pff_positionLinedUp',
#        'pff_hit', 'pff_hurry', 'pff_sack', 'pff_beatenByDefender',
#        'pff_hitAllowed', 'pff_hurryAllowed', 'pff_sackAllowed',
#        'pff_nflIdBlockedPlayer', 'pff_blockType', 'pff_backFieldBlock'],
#       dtype='object')

# %% [markdown]
# ### Displaying Player Data Format

# %%
print("-- Printing first 5 rows --\n\n")
display(player_data.head(5))
print("\n\n-- Printing Columns --\n\n")
print(player_data.columns)
# Out:
# -- Printing first 5 rows --
#    nflId height  weight   birthDate collegeName officialPosition  \
# 0  25511    6-4     225  1977-08-03    Michigan               QB
# 1  28963    6-5     240  1982-03-02   Miami, O.               QB
# 2  29550    6-4     328  1982-01-22    Arkansas                T
# 3  29851    6-2     225  1983-12-02  California               QB
# 4  30078    6-2     228  1982-11-24     Harvard               QB
#
#           displayName
# 0           Tom Brady
# 1  Ben Roethlisberger
# 2        Jason Peters
# 3       Aaron Rodgers
# 4    Ryan Fitzpatrick
# -- Printing Columns --
#
#
# Index(['nflId', 'height', 'weight', 'birthDate', 'collegeName',
#        'officialPosition', 'displayName'],
#       dtype='object')

# %% [markdown]
# ### Displaying Unique Positions

# %%
pos = player_data["officialPosition"]
print("----------------------------- Displaying Count For Each Unique Position -----------------------------")
display(pos.value_counts())
# Out:
# ----------------------------- Displaying Count For Each Unique Position -----------------------------
# WR     210
# CB     192
# DE     142
# OLB    136
# RB     126
# T      122
# TE     121
# DT     114
# G       99
# ILB     81
# FS      72
# SS      69
# QB      60
# C       55
# NT      34
# MLB     27
# FB      15
# LB       2
# DB       2
# Name: officialPosition, dtype: int64

# %% [markdown]
# ### Displaying Play Data Format

# %%
print("-- Printing first 5 rows --\n\n")
display(play_data.head(5))
print("\n\n-- Printing Columns --\n\n")
print(play_data.columns)
# Out:
# -- Printing first 5 rows --
#        gameId  playId                                    playDescription  \
# 0  2021090900      97  (13:33) (Shotgun) T.Brady pass incomplete deep...
# 1  2021090900     137  (13:18) (Shotgun) D.Prescott pass deep left to...
# 2  2021090900     187  (12:23) (Shotgun) D.Prescott pass short middle...
# 3  2021090900     282  (9:56) D.Prescott pass incomplete deep left to...
# 4  2021090900     349  (9:46) (Shotgun) D.Prescott pass incomplete sh...
#
#    quarter  down  yardsToGo possessionTeam defensiveTeam yardlineSide  \
# 0        1     3          2             TB           DAL           TB
# 1        1     1         10            DAL            TB          DAL
# 2        1     2          6            DAL            TB          DAL
# 3        1     1         10            DAL            TB           TB
# 4        1     3         15            DAL            TB           TB
#
#    yardlineNumber  ... foulNFLId3  absoluteYardlineNumber  offenseFormation  \
# 0              33  ...        NaN                    43.0           SHOTGUN
# 1               2  ...        NaN                   108.0             EMPTY
# 2              34  ...        NaN                    76.0           SHOTGUN
# 3              39  ...        NaN                    49.0        SINGLEBACK
# 4              44  ...        NaN                    54.0           SHOTGUN
#
#          personnelO  defendersInBox        personnelD  dropBackType  \
# 0  1 RB, 1 TE, 3 WR             6.0  4 DL, 2 LB, 5 DB   TRADITIONAL
# 1  1 RB, 2 TE, 2 WR             6.0  4 DL, 4 LB, 3 DB   TRADITIONAL
# 2  0 RB, 2 TE, 3 WR             6.0  3 DL, 3 LB, 5 DB   TRADITIONAL
# 3  1 RB, 2 TE, 2 WR             6.0  4 DL, 3 LB, 4 DB   TRADITIONAL
# 4  1 RB, 1 TE, 3 WR             7.0  3 DL, 4 LB, 4 DB   TRADITIONAL
#
#   pff_playAction  pff_passCoverage pff_passCoverageType
# 0              0           Cover-1                  Man
# 1              0           Cover-3                 Zone
# 2              0           Cover-3                 Zone
# 3              1           Cover-3                 Zone
# 4              0           Cover-3                 Zone
#
# [5 rows x 32 columns]
# -- Printing Columns --
#
#
# Index(['gameId', 'playId', 'playDescription', 'quarter', 'down', 'yardsToGo',
#        'possessionTeam', 'defensiveTeam', 'yardlineSide', 'yardlineNumber',
#        'gameClock', 'preSnapHomeScore', 'preSnapVisitorScore', 'passResult',
#        'penaltyYards', 'prePenaltyPlayResult', 'playResult', 'foulName1',
#        'foulNFLId1', 'foulName2', 'foulNFLId2', 'foulName3', 'foulNFLId3',
#        'absoluteYardlineNumber', 'offenseFormation', 'personnelO',
#        'defendersInBox', 'personnelD', 'dropBackType', 'pff_playAction',
#        'pff_passCoverage', 'pff_passCoverageType'],
#       dtype='object')

# %% [markdown]
# ### Displaying Tracking Data Format (Week 1)
#
# Here we identify rows with a particular frameId for a ball_snap event. How do we want to standardize the sequences? Do we drop all but 1 frame before the ball_snap?

# %%
print("-- Printing first 10 rows --\n\n")
display(tracking_w1_data_original.head(10))
print("\n\n-- Printing Columns --\n\n")
print(tracking_w1_data_original.columns)
print("\n\n-- Printing Number of Ball Snap Events -- \n\n")
print(tracking_w1_data_original.loc[(tracking_w1_data_original["event"] == "ball_snap") & (tracking_w1_data_original["frameId"] > 20)].shape[0])
# Out:
# -- Printing first 10 rows --
#        gameId  playId    nflId  frameId                     time  \
# 0  2021090900      97  25511.0        1  2021-09-10T00:26:31.100
# 1  2021090900      97  25511.0        2  2021-09-10T00:26:31.200
# 2  2021090900      97  25511.0        3  2021-09-10T00:26:31.300
# 3  2021090900      97  25511.0        4  2021-09-10T00:26:31.400
# 4  2021090900      97  25511.0        5  2021-09-10T00:26:31.500
# 5  2021090900      97  25511.0        6  2021-09-10T00:26:31.600
# 6  2021090900      97  25511.0        7  2021-09-10T00:26:31.700
# 7  2021090900      97  25511.0        8  2021-09-10T00:26:31.800
# 8  2021090900      97  25511.0        9  2021-09-10T00:26:31.900
# 9  2021090900      97  25511.0       10  2021-09-10T00:26:32.000
#
#    jerseyNumber team playDirection      x      y     s     a   dis       o  \
# 0          12.0   TB         right  37.77  24.22  0.29  0.30  0.03  165.16
# 1          12.0   TB         right  37.78  24.22  0.23  0.11  0.02  164.33
# 2          12.0   TB         right  37.78  24.24  0.16  0.10  0.01  160.24
# 3          12.0   TB         right  37.73  24.25  0.15  0.24  0.06  152.13
# 4          12.0   TB         right  37.69  24.26  0.25  0.18  0.04  148.33
# 5          12.0   TB         right  37.64  24.26  0.35  0.53  0.05  144.42
# 6          12.0   TB         right  37.56  24.26  0.54  1.05  0.08  137.49
# 7          12.0   TB         right  37.47  24.25  0.80  1.85  0.09  131.95
# 8          12.0   TB         right  37.38  24.24  0.99  2.03  0.09  129.85
# 9          12.0   TB         right  37.27  24.23  1.19  1.82  0.11  123.79
#
#       dir      event
# 0   84.99       None
# 1   92.87       None
# 2   68.55       None
# 3  296.85       None
# 4  287.55       None
# 5  282.72  ball_snap
# 6  272.95       None
# 7  267.49       None
# 8  263.48       None
# 9  263.77       None
# -- Printing Columns --
#
#
# Index(['gameId', 'playId', 'nflId', 'frameId', 'time', 'jerseyNumber', 'team',
#        'playDirection', 'x', 'y', 's', 'a', 'dis', 'o', 'dir', 'event'],
#       dtype='object')
#
#
# -- Printing Number of Ball Snap Events --
#
#
# 713

# %% [markdown]
# ### Data Cleaning
#
# Here we print the Nan values found in the Pandas Dataframe from the Week 1 tracking dataset. We can see that there are ~48 thousand rows with required data missing, and therefore we clean our data from dropping these values from our dataframe.

# %%
## See Empty Values and Clean Data
## Creating a copy and keeping the original
tracking_w1_data = tracking_w1_data_original.copy()

ball_mask = tracking_w1_data['nflId'].isnull()
ball_rows = tracking_w1_data[ball_mask]
mask = ball_rows['event'] == 'ball_snap'
ball_first_frame = ball_rows[mask]
#print(ball_first_frame.shape[0])
print(ball_first_frame['playId'].nunique())
nan_values = tracking_w1_data.isna().sum()
print(nan_values)
print("\n\nPrinting out Nan values below...\n\n")
display(tracking_w1_data[tracking_w1_data.isna().any(axis=1)])

tracking_w1_data= tracking_w1_data.dropna()
# Out:
# 3755
# gameId                0
# playId                0
# nflId            361486
# frameId               0
# time                  0
# jerseyNumber     361486
# team                  0
# playDirection         0
# x                     0
# y                     0
# s                     0
# a                     0
# dis                   0
# o                361486
# dir              361486
# event                 0
# dtype: int64
#
#
# Printing out Nan values below...
#             gameId  playId  nflId  frameId                     time  \
# 946     2021090900      97    NaN        1  2021-09-10T00:26:31.100
# 947     2021090900      97    NaN        2  2021-09-10T00:26:31.200
# 948     2021090900      97    NaN        3  2021-09-10T00:26:31.300
# 949     2021090900      97    NaN        4  2021-09-10T00:26:31.400
# 950     2021090900      97    NaN        5  2021-09-10T00:26:31.500
# ...            ...     ...    ...      ...                      ...
# 978944  2021110100    4433    NaN       54  2021-11-02T03:20:26.500
# 978945  2021110100    4433    NaN       55  2021-11-02T03:20:26.600
# 978946  2021110100    4433    NaN       56  2021-11-02T03:20:26.700
# 978947  2021110100    4433    NaN       57  2021-11-02T03:20:26.800
# 978948  2021110100    4433    NaN       58  2021-11-02T03:20:26.900
#
#         jerseyNumber      team playDirection      x      y     s     a   dis  \
# 946              NaN  football         right  42.92  24.04  0.00  0.00  0.00
# 947              NaN  football         right  42.23  23.91  0.25  0.12  0.70
# 948              NaN  football         right  42.17  23.89  0.19  0.73  0.07
# 949              NaN  football         right  42.10  23.89  0.04  1.86  0.07
# 950              NaN  football         right  41.82  23.91  1.19  6.28  0.28
# ...              ...       ...           ...    ...    ...   ...   ...   ...
# 978944           NaN  football         right  24.17  27.89  2.47  2.28  0.25
# 978945           NaN  football         right  24.36  28.03  2.36  2.16  0.24
# 978946           NaN  football         right  24.55  28.17  2.25  1.45  0.23
# 978947           NaN  football         right  24.73  28.31  2.28  0.72  0.23
# 978948           NaN  football         right  24.91  28.45  2.32  0.54  0.23
#
#          o  dir event
# 946    NaN  NaN  None
# 947    NaN  NaN  None
# 948    NaN  NaN  None
# 949    NaN  NaN  None
# 950    NaN  NaN  None
# ...     ..  ...   ...
# 978944 NaN  NaN  None
# 978945 NaN  NaN  None
# 978946 NaN  NaN  None
# 978947 NaN  NaN  None
# 978948 NaN  NaN  None
#
# [361486 rows x 16 columns]

# %% [markdown]
# ### Displaying Nan Values After Removal
#
# Here we provide evidence of no Nan values remaining in our dataset.

# %%
### Seeing remaining nan values

nan_values = tracking_w1_data.isna().sum()
print(nan_values)
print("\n\nPrinting out Nan values below...\n\n")
print(tracking_w1_data[tracking_w1_data.isna().any(axis=1)])
# Out:
# gameId           0
# playId           0
# nflId            0
# frameId          0
# time             0
# jerseyNumber     0
# team             0
# playDirection    0
# x                0
# y                0
# s                0
# a                0
# dis              0
# o                0
# dir              0
# event            0
# dtype: int64
#
#
# Printing out Nan values below...
#
#
# Empty DataFrame
# Columns: [gameId, playId, nflId, frameId, time, jerseyNumber, team, playDirection, x, y, s, a, dis, o, dir, event]
# Index: []

# %%
db_pos = player_data.loc[(player_data["officialPosition"] == "DB")]
db_pos
# Out:
#       nflId height  weight   birthDate collegeName officialPosition  \
# 1438  52912    6-0     210  1998-07-07  Notre Dame               DB
# 1582  53566   5-10     186         NaN         NaN               DB
#
#         displayName
# 1438  Jalen Elliott
# 1582      Tre Brown

# %% [markdown]
# ### Displaying Tracking Data and Player Data For Merge (Left Join)

# %%
print("--------------------------- Player Tracking Data ---------------------------")
display(tracking_w1_data.head(5))
print("-------------------------------- Player Data --------------------------------")
display(player_data.head(5))
# Out:
# --------------------------- Player Tracking Data ---------------------------
#        gameId  playId    nflId  frameId                     time  \
# 0  2021090900      97  25511.0        1  2021-09-10T00:26:31.100
# 1  2021090900      97  25511.0        2  2021-09-10T00:26:31.200
# 2  2021090900      97  25511.0        3  2021-09-10T00:26:31.300
# 3  2021090900      97  25511.0        4  2021-09-10T00:26:31.400
# 4  2021090900      97  25511.0        5  2021-09-10T00:26:31.500
#
#    jerseyNumber team playDirection      x      y     s     a   dis       o  \
# 0          12.0   TB         right  37.77  24.22  0.29  0.30  0.03  165.16
# 1          12.0   TB         right  37.78  24.22  0.23  0.11  0.02  164.33
# 2          12.0   TB         right  37.78  24.24  0.16  0.10  0.01  160.24
# 3          12.0   TB         right  37.73  24.25  0.15  0.24  0.06  152.13
# 4          12.0   TB         right  37.69  24.26  0.25  0.18  0.04  148.33
#
#       dir event
# 0   84.99  None
# 1   92.87  None
# 2   68.55  None
# 3  296.85  None
# 4  287.55  None
# -------------------------------- Player Data --------------------------------
#    nflId height  weight   birthDate collegeName officialPosition  \
# 0  25511    6-4     225  1977-08-03    Michigan               QB
# 1  28963    6-5     240  1982-03-02   Miami, O.               QB
# 2  29550    6-4     328  1982-01-22    Arkansas                T
# 3  29851    6-2     225  1983-12-02  California               QB
# 4  30078    6-2     228  1982-11-24     Harvard               QB
#
#           displayName
# 0           Tom Brady
# 1  Ben Roethlisberger
# 2        Jason Peters
# 3       Aaron Rodgers
# 4    Ryan Fitzpatrick

# %% [markdown]
# ### Left Join Player and Player Tracking Data
#
# We will left join into the Player Tracking Dataset on the nflId column.

# %%
player_positions = player_data[["nflId","officialPosition"]]
player_positions_isolated = player_positions.loc[(player_positions["officialPosition"] == "TE")|(player_positions["officialPosition"] == "WR")|(player_positions["officialPosition"] == "SS")|(player_positions["officialPosition"] == "FS")|(player_positions["officialPosition"] == "CB")|(player_positions["officialPosition"] == "DB")] 
player_tracking = tracking_w1_data.merge(player_positions_isolated,on="nflId",how="left")
player_tracking_all = tracking_w1_data.merge(player_positions,on="nflId",how="inner")
player_tracking_isolated = tracking_w1_data.merge(player_positions_isolated,on="nflId",how="inner")
#print(player_tracking_isolated.loc[(player_tracking_isolated["nflId"]=="NA")])
print("----------------------------------- Results of Left Join With All Positions ----------------------------------")
display(player_tracking)
print("-------------------------------- Results of Inner Join With Isolated Positions --------------------------------")
display(player_tracking_isolated)
# Out:
# ----------------------------------- Results of Left Join With All Positions ----------------------------------
#              gameId  playId    nflId  frameId                     time  \
# 0        2021090900      97  25511.0        1  2021-09-10T00:26:31.100
# 1        2021090900      97  25511.0        2  2021-09-10T00:26:31.200
# 2        2021090900      97  25511.0        3  2021-09-10T00:26:31.300
# 3        2021090900      97  25511.0        4  2021-09-10T00:26:31.400
# 4        2021090900      97  25511.0        5  2021-09-10T00:26:31.500
# ...             ...     ...      ...      ...                      ...
# 7952687  2021110100    4433  53449.0       54  2021-11-02T03:20:26.500
# 7952688  2021110100    4433  53449.0       55  2021-11-02T03:20:26.600
# 7952689  2021110100    4433  53449.0       56  2021-11-02T03:20:26.700
# 7952690  2021110100    4433  53449.0       57  2021-11-02T03:20:26.800
# 7952691  2021110100    4433  53449.0       58  2021-11-02T03:20:26.900
#
#          jerseyNumber team playDirection      x      y     s     a   dis  \
# 0                12.0   TB         right  37.77  24.22  0.29  0.30  0.03
# 1                12.0   TB         right  37.78  24.22  0.23  0.11  0.02
# 2                12.0   TB         right  37.78  24.24  0.16  0.10  0.01
# 3                12.0   TB         right  37.73  24.25  0.15  0.24  0.06
# 4                12.0   TB         right  37.69  24.26  0.25  0.18  0.04
# ...               ...  ...           ...    ...    ...   ...   ...   ...
# 7952687          89.0  NYG         right  49.44  48.85  1.43  3.20  0.14
# 7952688          89.0  NYG         right  49.43  48.99  1.34  2.85  0.13
# 7952689          89.0  NYG         right  49.40  49.11  1.32  2.42  0.13
# 7952690          89.0  NYG         right  49.33  49.22  1.29  2.18  0.13
# 7952691          89.0  NYG         right  49.26  49.32  1.25  1.75  0.12
#
#               o     dir event officialPosition
# 0        165.16   84.99  None              NaN
# 1        164.33   92.87  None              NaN
# 2        160.24   68.55  None              NaN
# 3        152.13  296.85  None              NaN
# 4        148.33  287.55  None              NaN
# ...         ...     ...   ...              ...
# 7952687  270.45    2.03  None               WR
# 7952688  273.20  349.13  None               WR
# 7952689  275.46  338.05  None               WR
# 7952690  277.09  326.21  None               WR
# 7952691  278.42  318.04  None               WR
#
# [7952692 rows x 17 columns]
# -------------------------------- Results of Inner Join With Isolated Positions --------------------------------
#              gameId  playId    nflId  frameId                     time  \
# 0        2021090900      97  35481.0        1  2021-09-10T00:26:31.100
# 1        2021090900      97  35481.0        2  2021-09-10T00:26:31.200
# 2        2021090900      97  35481.0        3  2021-09-10T00:26:31.300
# 3        2021090900      97  35481.0        4  2021-09-10T00:26:31.400
# 4        2021090900      97  35481.0        5  2021-09-10T00:26:31.500
# ...             ...     ...      ...      ...                      ...
# 3245694  2021110100    1480  53500.0       26  2021-11-02T01:12:57.400
# 3245695  2021110100    1480  53500.0       27  2021-11-02T01:12:57.500
# 3245696  2021110100    1480  53500.0       28  2021-11-02T01:12:57.600
# 3245697  2021110100    1480  53500.0       29  2021-11-02T01:12:57.700
# 3245698  2021110100    1480  53500.0       30  2021-11-02T01:12:57.800
#
#          jerseyNumber team playDirection      x      y     s     a   dis  \
# 0                87.0   TB         right  41.08  29.15  0.31  0.43  0.03
# 1                87.0   TB         right  41.34  29.45  0.38  1.02  0.40
# 2                87.0   TB         right  41.53  29.39  0.61  1.10  0.20
# 3                87.0   TB         right  41.53  29.38  0.53  0.76  0.01
# 4                87.0   TB         right  41.54  29.36  0.97  1.52  0.03
# ...               ...  ...           ...    ...    ...   ...   ...   ...
# 3245694          33.0  NYG          left  43.17  39.28  7.10  2.55  0.71
# 3245695          33.0  NYG          left  42.46  39.32  7.18  2.89  0.72
# 3245696          33.0  NYG          left  41.73  39.32  7.30  3.14  0.73
# 3245697          33.0  NYG          left  40.98  39.27  7.46  3.32  0.74
# 3245698          33.0  NYG          left  40.23  39.18  7.60  3.53  0.76
#
#               o     dir event officialPosition
# 0         35.96  238.77  None               TE
# 1        102.09   29.56  None               TE
# 2         68.16   71.57  None               TE
# 3         73.06   82.44  None               TE
# 4         76.60   75.14  None               TE
# ...         ...     ...   ...              ...
# 3245694  283.98  275.50  None               CB
# 3245695  276.80  272.18  None               CB
# 3245696  268.66  268.97  None               CB
# 3245697  254.04  265.33  None               CB
# 3245698  250.99  261.62  None               CB
#
# [3245699 rows x 17 columns]

# %% [markdown]
# ### Displaying Unique Position Count After Data Cleaning

# %%
pos = player_tracking_isolated["officialPosition"]
print("----------------------------- Displaying Count For Each Unique Position -----------------------------")
display(pos.value_counts())
# Out:
# ----------------------------- Displaying Count For Each Unique Position -----------------------------
# CB    1008898
# WR     972192
# TE     445266
# FS     429395
# SS     386152
# DB       3796
# Name: officialPosition, dtype: int64

# %% [markdown]
# ### Encoding Categorical Data
#
# In our tracking dataset we identify 3 categorical columns (team,playDirection,event) with string values. For each of these columns, we will create an encoded dictionary that holds the corresponding numerical values for each unique category found in each of those columns.

# %%
# Encoding categorical data
categorical_data = ["team","playDirection","event","officialPosition"]
category_codes = {}

w1_data_copy = player_tracking_isolated.copy()

for i in player_tracking_isolated:
    if i in categorical_data:
        specific_codes = {}
        player_tracking_isolated[i] = player_tracking_isolated[i].astype("category")
        player_tracking_isolated[i] = player_tracking_isolated[i].cat.codes
        coded = player_tracking_isolated[i].unique()#
        count = 0
        for j in w1_data_copy[i].unique():
           specific_codes[j] = coded[count]
           count += 1
        category_codes[i] = specific_codes

for i in category_codes:
  print("{} -".format(i))
  for j in category_codes[i]:
    print("{}: {}".format(j, category_codes[i][j]))
# Out:
# team -
# TB: 29
# DAL: 8
# PHI: 25
# ATL: 1
# ARI: 0
# PIT: 26
# BUF: 3
# NYJ: 24
# CAR: 4
# JAX: 14
# MIN: 20
# CIN: 6
# SF: 28
# DET: 10
# HOU: 12
# IND: 13
# SEA: 27
# TEN: 30
# LAC: 17
# WAS: 31
# KC: 15
# CLE: 7
# MIA: 19
# NE: 21
# CHI: 5
# NO: 22
# GB: 11
# LV: 18
# DEN: 9
# NYG: 23
# LA: 16
# BAL: 2
# playDirection -
# right: 1
# left: 0
# event -
# None: 0
# ball_snap: 4
# autoevent_passforward: 2
# pass_forward: 16
# pass_arrived: 15
# play_action: 21
# autoevent_passinterrupted: 3
# autoevent_ballsnap: 1
# man_in_motion: 13
# shift: 25
# pass_outcome_incomplete: 18
# pass_outcome_caught: 17
# run: 24
# qb_sack: 22
# qb_strip_sack: 23
# pass_tipped: 19
# line_set: 12
# fumble_offense_recovered: 8
# tackle: 26
# fumble: 7
# first_contact: 6
# handoff: 9
# out_of_bounds: 14
# dropped_pass: 5
# penalty_flag: 20
# huddle_break_offense: 10
# lateral: 11
# officialPosition -
# TE: 4
# WR: 5
# CB: 0
# SS: 3
# FS: 2
# DB: 1

# %% [markdown]
# ### Viewing Auto Event Ball Snap In Comparison with Ball Snap Events

# %%
ball_snap_events =  player_tracking_isolated.loc[(player_tracking_isolated["event"] == 4)][["gameId","playId","nflId","event","frameId"]]
auto_event_ball_snap_events =  player_tracking_isolated.loc[(player_tracking_isolated["event"] == 1)][["gameId","playId","nflId","event","frameId"]]
intersect_events = pd.merge(ball_snap_events,auto_event_ball_snap_events,how="inner",on=["gameId","playId","nflId"])
display(ball_snap_events)
display(auto_event_ball_snap_events)
print("------------------------------- Displaying Intersection of Events For a Given Game, Play and Player -------------------------------")
display(intersect_events)
# Out:
#              gameId  playId    nflId  event  frameId
# 5        2021090900      97  35481.0      4        6
# 48       2021090900     410  35481.0      4        6
# 75       2021090900     434  35481.0      4        6
# 103      2021090900     456  35481.0      4        6
# 139      2021090900     480  35481.0      4        6
# ...             ...     ...      ...    ...      ...
# 3245461  2021110100     775  53500.0      4        6
# 3245503  2021110100     797  53500.0      4        6
# 3245552  2021110100    1160  53500.0      4        6
# 3245588  2021110100    1182  53500.0      4        6
# 3245674  2021110100    1480  53500.0      4        6
#
# [76614 rows x 5 columns]
#              gameId  playId    nflId  event  frameId
# 447      2021090900    1227  35481.0      1        6
# 688      2021090900    2871  35481.0      1        6
# 835      2021090900    3110  35481.0      1        6
# 890      2021090900    3110  35481.0      1       61
# 923      2021090900    3134  35481.0      1        6
# ...             ...     ...      ...    ...      ...
# 3244830  2021103108    1632  53526.0      1        7
# 3244891  2021103108    2292  43397.0      1        7
# 3245057  2021103108    2711  43397.0      1        7
# 3245126  2021103108    3279  43397.0      1        7
# 3245368  2021110100     531  53500.0      1        7
#
# [33776 rows x 5 columns]
# ------------------------------- Displaying Intersection of Events For a Given Game, Play and Player -------------------------------
#            gameId  playId    nflId  event_x  frameId_x  event_y  frameId_y
# 0      2021090900    1227  35481.0        4          7        1          6
# 1      2021090900    2871  35481.0        4          7        1          6
# 2      2021090900    3110  35481.0        4         62        1          6
# 3      2021090900    3110  35481.0        4         62        1         61
# 4      2021090900    3134  35481.0        4          7        1          6
# ...           ...     ...      ...      ...        ...      ...        ...
# 33762  2021103108    1632  53526.0        4          6        1          7
# 33763  2021103108    2292  43397.0        4          6        1          7
# 33764  2021103108    2711  43397.0        4          6        1          7
# 33765  2021103108    3279  43397.0        4          6        1          7
# 33766  2021110100     531  53500.0        4          6        1          7
#
# [33767 rows x 7 columns]

# %% [markdown]
# ### Defining Sequence Terminal Events

# %%
event_dict = category_codes['event']
terminal_events = ['qb_sack','pass_outcome_incomplete','qb_strip_sack','pass_outcome_caught','pass_tipped','fumble','fumble_offense_recovered','lateral','run','pass_arrived']
terminal_events = [event_dict[x] for x in terminal_events] # QB Sack, Pass Outcome Incomplete, QB Strip Sack, Pass Outcome Caught, Pass Tipped, Fumble, Fumple Recovered, Lateral, Run, Pass Arrived

# %% [markdown]
# ### Creating Functions For Sequence Generation
#
# Here we define functions that will take in a dataframe of tracking data and generate sequences. The first function will generate sequences for a single play and game, returning a dictionary with keys corresponding to each player in that play. This will be used by dataframes with no positional filters to graph entire plays.

# %%
def generate_sequences_single_play(df):    
    id_columns = df[["officialPosition","nflId"]]
    sequence_dict_keys = id_columns.drop_duplicates()
    sequence_dict_keys_arr = list(sequence_dict_keys.itertuples(index=False,name=None))
    sequence_dict = dict.fromkeys(sequence_dict_keys_arr,[])
    current_seq = []
    nflID = -1
    position = -1
    collect = False
    terminal = False
    count = 0
    for row in df.itertuples():
        if not(collect):
            collect = (row.event == 4)
        if not(terminal):
            terminal= (row.event in terminal_events)    # Play terminal or changes from coached D to responsive D
        if (nflID == -1) or (nflID != row.nflId):
            if len(current_seq) > 0:
                sequence_dict[(position,nflID)] = current_seq
                current_seq = []
                count +=1
            terminal = (row.event in terminal_events)
            collect = (row.event == 4)
            nflID = row.nflId
            position = row.officialPosition
            if collect and len(current_seq) < 90 and not(terminal):
                current_seq.append([row.frameId,row.team,row.x,row.y,row.s,row.o,row.event]) #removed row.time, frames are 1/10 of a second
        elif nflID == row.nflId and collect and not(terminal):
            current_seq.append([row.frameId,row.team,row.x,row.y,row.s,row.o,row.event])
    print(f"Sequences generated: {count}")
    return (sequence_dict)

# %% [markdown]
# This second function will generate a nested dictionary. The outer dictionary will have a composite key identifying each play from a game. The inner key will correspond to the player of a given play. This nested dictionary will be used to isolate plays and generate sequences for all of the tracking data, while having them divided by play and player. The function will also determine what events were captured in the dataframe. Finally, the function also returns a 3D array of sequences, containing every sequence of the inner dictionaries.

# %%
def generate_sequences(df):
    sequence_dict = defaultdict(dict)
    sequence_dict_dense = defaultdict(dict)

    captured_events = []
    seq_arr = []
    current_seq = []
    current_seq_dense = []

    gameID = -1
    playID = -1
    nflID = -1
    position = -1
    collect = False
    terminal = False
    count = 0
    for row in df.itertuples():
        if not(collect):
            collect = (row.event == 4)
        if not(terminal):
            terminal= (row.event in terminal_events)    # Play terminal or changes from coached D to responsive D
        if (gameID == -1 or playID == -1 or nflID == -1) or (gameID != row.gameId or playID != row.playId or nflID != row.nflId):
            if len(current_seq) > 10:
                sequence_dict[(gameID,playID)][(position,nflID)] = current_seq
                sequence_dict_dense[(gameID,playID)][(position,nflID)] = current_seq_dense

                seq_arr.append(current_seq_dense)

                current_seq = []
                current_seq_dense = []

                count +=1
                
            terminal = (row.event in terminal_events)
            collect = (row.event == 4)
            gameID = row.gameId
            playID = row.playId
            nflID = row.nflId
            position = row.officialPosition
            if collect and len(current_seq) < 90 and not(terminal):
                current_seq.append([row.frameId,row.team,row.x,row.y,row.s,row.o,row.event]) #removed row.time, frames are 1/10 of a second
                current_seq_dense.append([row.x,row.y,row.o]) #removes s a dis row.s,row.a,row.dis,

                if not(row.event in captured_events) and row.event != 0:
                    captured_events.append(row.event)

        elif gameID == row.gameId and playID == row.playId and nflID == row.nflId and collect and not(terminal):
            current_seq.append([row.frameId,row.team,row.x,row.y,row.s,row.o,row.event])
            current_seq_dense.append([row.x,row.y,row.o]) #row.s,row.a,row.dis,

            if not(row.event in captured_events) and row.event != 0:
                captured_events.append(row.event)
    print(f"Sequences generated: {count}")
    return (seq_arr,captured_events,sequence_dict,sequence_dict_dense)

# %%
'''skip = False
            flip_y = row.y>los_y
            mask = (ball_first_frame['gameId'] == row.gameId) & (ball_first_frame['playId'] == row.playId)
            ball_row = ball_first_frame[mask]
            if ball_row.empty:
                skip = True
            else:
                los_x = ball_row.iloc[0]['x']
            '''
'''if row.playDirection == 0:
                    x = row.x - los_x
                    x = -x
                    x = x + los_x
                else:
                    x = row.x
                if flip_y:
                    y = row.y-los_y
                    y = -y
                    y = y+los_y
                else:
                    y = row.y'''
# Out:
# 'if row.playDirection == 0:\n                    x = row.x - los_x\n                    x = -x\n                    x = x + los_x\n                else:\n                    x = row.x\n                if flip_y:\n                    y = row.y-los_y\n                    y = -y\n                    y = y+los_y\n                else:\n                    y = row.y'

# %% [markdown]
# ### Creating Sequences for the Week 1 Tracking Dataset
#
# Here we generate sequences for plays and players using our week 1 player tracking dataset. Below we display an entry to our sequences array which corresponds to a sequence for a given play and player. We can see that this is a sequence of arrays of size 12 with numbers from our tracking dataset and encoded categorical columns. This particular sequence is 43 frames long (note that we have dropped id columns and datetime).

# %%
sequences,captured_events,seq_dict,seq_dict_dense = generate_sequences(player_tracking_isolated)
print("Printing Example Sequence")
print(sequences[0])
print(f"\n\nNumber of entries in this sequence: {len(sequences[0])}")
#player_tracking_isolated_copy = player_tracking_isolated.copy()
#player_tracking_normalized = normalize_data(player_tracking_isolated_copy)
#sequences_standardized,_,seq_dict_standardized = generate_sequences(player_tracking_standardized)
#sequences_final,_,seq_dict_final = generate_sequences(player_tracking_normalized)
#sequences,captured_events,seq_dict,seq_dict_dense = generate_sequences(player_tracking_isolated)

#print("Printing Example Standardized Sequence")
#print(sequences[0])
#print(f"\n\nNumber of entries in this sequence: {len(sequences[0])}")
#sequences = seq_standardization(seq_arr=sequences)
#print(seq_dict[(2021090900, 97)][(3, 35481.0)])
# Out:
# Sequences generated: 76525
# Printing Example Sequence
# [[41.65, 29.34, 78.97], [41.75, 29.36, 82.37], [41.87, 29.42, 73.75], [42.04, 29.55, 75.34], [42.21, 29.71, 78.47], [42.39, 29.89, 72.68], [42.57, 30.13, 66.34], [42.74, 30.4, 56.5], [42.9, 30.69, 45.23], [43.04, 31.01, 24.29], [43.16, 31.35, 19.14], [43.29, 31.71, 8.45], [43.42, 32.1, 6.52], [43.54, 32.51, 7.65], [43.64, 32.95, 14.52], [43.74, 33.41, 13.3], [43.84, 33.89, 6.26], [43.96, 34.39, 9.51], [44.07, 34.91, 13.58], [44.2, 35.47, 8.41], [44.35, 36.06, 2.99], [44.5, 36.65, 359.99], [44.63, 37.25, 14.51], [44.77, 37.87, 24.5], [44.9, 38.5, 33.03], [45.04, 39.15, 41.52], [45.2, 39.79, 55.25], [45.35, 40.43, 65.65], [45.52, 41.07, 74.66], [45.71, 41.68, 80.99], [45.92, 42.3, 86.06], [46.13, 42.9, 91.04], [46.36, 43.5, 93.12], [46.6, 44.1, 93.12], [46.88, 44.67, 91.58], [47.17, 45.2, 92.86], [47.49, 45.71, 94.65], [47.82, 46.17, 94.65]]
#
#
# Number of entries in this sequence: 38

# %%
last_five = list(seq_dict_dense.items())[-5:]

# Print the last 5 key-value pairs
for key, value in last_five:
    print(key, value)
# Out:
# (2021091300, 4641) {(0, 38592.0): [[34.08, 9.19, 290.54], [34.09, 9.19, 299.66], [34.11, 9.18, 316.75], [34.15, 9.18, 334.02], [34.22, 9.18, 343.81], [34.31, 9.19, 348.74], [34.45, 9.2, 356.12], [34.62, 9.22, 5.69], [34.82, 9.24, 8.58], [35.07, 9.26, 7.44], [35.35, 9.28, 8.5], [35.67, 9.3, 7.88], [36.02, 9.32, 7.88], [36.41, 9.32, 7.88], [36.83, 9.31, 7.88], [37.28, 9.3, 6.35], [37.74, 9.27, 4.66], [38.23, 9.22, 4.66], [38.72, 9.15, 5.39], [39.24, 9.08, 5.39], [39.77, 8.99, 5.39], [40.3, 8.9, 3.86], [40.85, 8.79, 3.86], [41.41, 8.69, 1.89], [41.99, 8.58, 2.76], [42.57, 8.48, 5.45], [43.16, 8.38, 6.76], [43.75, 8.29, 8.07], [44.34, 8.2, 9.09], [44.92, 8.11, 10.63], [45.47, 8.04, 10.63], [46.0, 7.96, 8.38], [46.5, 7.9, 8.38], [46.95, 7.83, 4.28], [47.32, 7.74, 350.6], [47.63, 7.64, 343.95], [47.88, 7.52, 337.27], [48.05, 7.39, 329.54], [48.15, 7.23, 318.37], [48.18, 7.05, 307.3], [48.13, 6.84, 304.72], [48.03, 6.61, 303.86], [47.86, 6.36, 302.06], [47.67, 6.09, 303.48], [47.45, 5.81, 307.19], [47.21, 5.52, 310.94], [46.97, 5.22, 316.61], [46.74, 4.91, 319.89], [46.51, 4.6, 325.37]], (5, 41230.0): [[29.25, 10.9, 76.35], [29.27, 10.9, 76.35], [29.28, 10.9, 76.35], [29.31, 10.9, 77.41], [29.33, 10.9, 78.83], [29.38, 10.9, 82.98], [29.5, 10.91, 86.54], [29.68, 10.91, 92.15], [29.93, 10.9, 93.2], [30.24, 10.88, 92.58], [30.61, 10.86, 94.09], [31.03, 10.85, 99.08], [31.51, 10.81, 99.08], [32.03, 10.76, 95.94], [32.59, 10.7, 97.85], [33.18, 10.64, 100.59], [33.79, 10.56, 102.72], [34.43, 10.47, 100.87], [35.09, 10.37, 99.89], [35.77, 10.26, 99.89], [36.46, 10.16, 103.53], [37.17, 10.06, 102.19], [37.88, 9.96, 99.94], [38.61, 9.87, 96.96], [39.34, 9.77, 96.96], [40.08, 9.69, 99.97], [40.8, 9.61, 103.86], [41.52, 9.54, 105.3], [42.22, 9.46, 106.12], [42.91, 9.39, 110.07], [43.56, 9.32, 112.85], [44.18, 9.24, 117.57], [44.75, 9.15, 122.98], [45.26, 9.02, 138.04], [45.72, 8.89, 145.71], [46.11, 8.73, 157.28], [46.43, 8.55, 168.54], [46.69, 8.33, 194.64], [46.89, 8.1, 207.55], [47.04, 7.84, 218.04], [47.13, 7.56, 227.02], [47.16, 7.27, 231.88], [47.14, 6.97, 236.33], [47.09, 6.68, 240.35], [47.01, 6.4, 243.43], [46.9, 6.14, 244.46], [46.78, 5.9, 245.15], [46.64, 5.68, 246.25], [46.5, 5.48, 247.32]], (4, 46155.0): [[28.7, 31.15, 82.14], [28.71, 31.16, 82.14], [28.72, 31.17, 82.14], [28.75, 31.18, 80.9], [28.81, 31.2, 80.9], [28.89, 31.24, 84.42], [29.04, 31.29, 87.17], [29.23, 31.35, 89.03], [29.46, 31.38, 89.03], [29.72, 31.41, 94.34], [30.01, 31.42, 99.36], [30.32, 31.4, 105.05], [30.66, 31.33, 106.73], [31.01, 31.2, 114.61], [31.36, 31.01, 124.55], [31.69, 30.74, 136.38], [32.01, 30.4, 147.75], [32.3, 29.99, 163.47], [32.56, 29.54, 178.1], [32.8, 29.03, 191.28], [33.01, 28.47, 193.22], [33.18, 27.87, 193.22], [33.33, 27.23, 197.92], [33.45, 26.56, 201.53], [33.55, 25.86, 204.66], [33.64, 25.13, 201.93], [33.72, 24.39, 201.93], [33.8, 23.64, 201.93], [33.88, 22.87, 204.89], [33.96, 22.1, 204.26], [34.05, 21.33, 205.53], [34.15, 20.55, 204.17], [34.27, 19.77, 202.99], [34.4, 19.0, 203.76], [34.54, 18.23, 203.76], [34.7, 17.46, 203.76], [34.87, 16.71, 201.95], [35.05, 15.97, 202.62], [35.25, 15.24, 203.69], [35.48, 14.52, 202.38], [35.72, 13.82, 200.2], [35.98, 13.14, 194.82], [36.24, 12.48, 191.04], [36.53, 11.83, 186.58], [36.81, 11.21, 184.37], [37.1, 10.61, 177.71], [37.39, 10.03, 173.15], [37.67, 9.47, 167.28], [37.94, 8.94, 164.61]], (3, 47810.0): [[31.95, 19.59, 311.54], [31.79, 19.78, 305.22], [31.63, 19.96, 302.49], [31.49, 20.13, 300.93], [31.36, 20.29, 300.25], [31.23, 20.43, 296.71], [31.12, 20.56, 293.58], [31.03, 20.67, 293.58], [30.95, 20.76, 291.07], [30.88, 20.83, 291.07], [30.83, 20.87, 290.1], [30.78, 20.87, 287.94], [30.74, 20.84, 287.94], [30.69, 20.77, 286.61], [30.63, 20.64, 284.64], [30.56, 20.47, 281.51], [30.49, 20.26, 279.01], [30.41, 20.01, 277.11], [30.34, 19.72, 274.74], [30.29, 19.39, 271.96], [30.24, 19.04, 265.44], [30.22, 18.65, 258.95], [30.24, 18.23, 253.68], [30.3, 17.78, 247.97], [30.39, 17.32, 238.64],  ...
# (2021091300, 4691) {(0, 38592.0): [[34.51, 46.14, 239.38], [34.57, 46.17, 238.74], [34.62, 46.2, 237.49], [34.68, 46.23, 224.69], [34.74, 46.27, 214.18], [34.84, 46.31, 209.33], [34.98, 46.37, 208.63], [35.17, 46.45, 202.42], [35.41, 46.53, 199.9], [35.69, 46.63, 199.9], [36.01, 46.74, 197.2], [36.36, 46.85, 194.92], [36.74, 46.96, 192.61], [37.13, 47.07, 189.79], [37.54, 47.18, 187.54], [37.96, 47.29, 187.54], [38.4, 47.41, 188.48], [38.84, 47.52, 188.48], [39.3, 47.62, 188.48], [39.74, 47.72, 189.09], [40.19, 47.81, 189.09], [40.62, 47.9, 193.27], [41.04, 47.99, 193.27], [41.43, 48.06, 193.27], [41.79, 48.12, 191.18], [42.11, 48.15, 198.03], [42.4, 48.17, 202.19], [42.63, 48.17, 204.2], [42.8, 48.15, 205.0], [42.92, 48.12, 207.78], [42.98, 48.08, 211.06], [42.98, 48.03, 212.0], [42.94, 47.99, 211.23], [42.85, 47.93, 209.29], [42.73, 47.87, 210.59], [42.58, 47.79, 211.68]], (5, 41230.0): [[29.05, 34.52, 103.32], [29.05, 34.52, 103.32], [29.06, 34.52, 102.07], [29.09, 34.51, 102.07], [29.15, 34.48, 103.96], [29.26, 34.42, 103.96], [29.42, 34.33, 104.9], [29.61, 34.21, 104.05], [29.85, 34.04, 106.17], [30.13, 33.86, 109.3], [30.44, 33.64, 113.47], [30.79, 33.4, 117.97], [31.16, 33.13, 124.34], [31.56, 32.85, 127.9], [31.96, 32.54, 131.35], [32.37, 32.24, 136.84], [32.75, 31.95, 149.86], [33.13, 31.66, 152.96], [33.47, 31.4, 163.73], [33.78, 31.17, 180.52], [34.06, 30.96, 198.44], [34.3, 30.78, 214.81], [34.51, 30.6, 224.54], [34.68, 30.43, 234.89], [34.82, 30.25, 238.0], [34.92, 30.04, 241.44], [35.0, 29.79, 244.19], [35.05, 29.51, 246.93], [35.08, 29.2, 246.93], [35.09, 28.84, 246.93], [35.09, 28.45, 244.61], [35.08, 28.01, 242.49], [35.06, 27.54, 240.41], [35.03, 27.04, 234.75], [34.99, 26.52, 234.75], [34.94, 25.97, 228.83]], (4, 46155.0): [[29.09, 18.05, 80.64], [29.18, 18.06, 85.83], [29.29, 18.06, 83.5], [29.45, 18.04, 90.42], [29.68, 18.02, 93.46], [29.96, 17.98, 89.11], [30.28, 17.92, 84.57], [30.67, 17.84, 87.09], [31.1, 17.74, 93.17], [31.59, 17.62, 98.39], [32.11, 17.47, 101.79], [32.67, 17.3, 103.16], [33.25, 17.1, 103.16], [33.85, 16.88, 103.77], [34.48, 16.66, 103.77], [35.13, 16.43, 103.77], [35.8, 16.22, 102.25], [36.49, 16.01, 96.55], [37.2, 15.82, 95.22], [37.92, 15.66, 95.22], [38.65, 15.53, 92.75], [39.4, 15.42, 88.25], [40.13, 15.34, 85.44], [40.86, 15.28, 82.76], [41.57, 15.23, 76.27], [42.23, 15.21, 70.49], [42.84, 15.18, 66.39], [43.39, 15.17, 52.78], [43.88, 15.15, 36.03], [44.3, 15.14, 11.49], [44.64, 15.11, 347.19], [44.91, 15.08, 339.36], [45.1, 15.04, 332.98], [45.23, 14.99, 333.84], [45.29, 14.93, 342.39], [45.31, 14.87, 350.5]], (5, 47808.0): [[28.58, 39.16, 80.2], [28.61, 39.15, 80.9], [28.66, 39.15, 79.53], [28.76, 39.14, 79.53], [28.92, 39.14, 73.67], [29.13, 39.15, 74.91], [29.42, 39.17, 76.51], [29.75, 39.21, 73.56], [30.13, 39.26, 66.59], [30.56, 39.34, 66.59], [31.04, 39.42, 65.91], [31.57, 39.53, 61.96], [32.14, 39.64, 58.41], [32.76, 39.77, 56.22], [33.4, 39.9, 56.22], [34.07, 40.02, 62.06], [34.75, 40.12, 69.57], [35.45, 40.21, 80.98], [36.15, 40.28, 90.47], [36.86, 40.32, 98.97], [37.56, 40.32, 112.54], [38.24, 40.27, 126.33], [38.91, 40.17, 132.8], [39.56, 40.01, 141.33], [40.18, 39.8, 148.65], [40.77, 39.53, 160.88], [41.32, 39.2, 166.33], [41.82, 38.83, 170.4], [42.28, 38.41, 173.2], [42.7, 37.96, 177.16], [43.07, 37.48, 180.11], [43.39, 36.98, 183.62], [43.67, 36.47, 184.85], [43.89, 35.96, 184.14], [44.08, 35.46, 183.01], [44.21, 34.96, 183.01]], (3, 47810.0): [[37.03, 16.07, 309.57], [37.06, 16.06, 311.06], [37.1, 16.04, 310.34], [37.14, 16.03, 310.34], [37.16, 16.02, 309.17], [37.21, 16.01, 310.32], [37.3, 15.98, 307.61], [37.44, 15.95, 309.28], [37.63, 15.9, 311.16], [37.86, 15.82, 314.52], [38.13, 15.72, 317.63], [38.43, 15.62, 322.35], [38.75, 15.5, 328.69], [39.09, 15.37, 337.15], [39.45, 15.23, 346.97], [39.83, 15.09, 356.36], [40.22, 14.94, 0.84], [40.63, 14.8, 8.56], [41.07, 14.66, 14.69], [41.52, 14.54, 19.52], [42.0, 14.44, 16.77], [42.49, 14.37, 19.27], [43.01, 14.32, 2 ...
# (2021091300, 4736) {(0, 38592.0): [[47.64, 41.74, 256.3], [47.66, 41.8, 256.9], [47.69, 41.84, 255.99], [47.72, 41.88, 251.4], [47.75, 41.93, 248.91], [47.8, 41.99, 241.25], [47.88, 42.08, 235.8], [47.98, 42.18, 229.09], [48.11, 42.29, 217.48], [48.27, 42.41, 213.86], [48.47, 42.54, 207.24], [48.7, 42.67, 200.99], [48.97, 42.8, 197.65], [49.26, 42.91, 195.07], [49.58, 43.01, 189.36], [49.92, 43.09, 185.37], [50.29, 43.15, 185.37], [50.69, 43.19, 185.37], [51.12, 43.19, 182.47], [51.57, 43.17, 182.47], [52.04, 43.12, 183.34], [52.53, 43.03, 187.07], [53.04, 42.91, 185.4], [53.56, 42.77, 186.69], [54.08, 42.61, 186.69], [54.62, 42.42, 183.86], [55.13, 42.2, 180.13], [55.64, 41.98, 179.34], [56.13, 41.74, 178.72]], (5, 41230.0): [[42.11, 40.72, 97.08], [42.12, 40.72, 95.75], [42.14, 40.72, 93.39], [42.18, 40.72, 90.33], [42.28, 40.74, 93.02], [42.39, 40.75, 92.07], [42.53, 40.76, 87.42], [42.73, 40.77, 86.21], [42.98, 40.79, 87.44], [43.27, 40.8, 82.95], [43.61, 40.82, 81.99], [44.0, 40.85, 78.84], [44.44, 40.88, 77.55], [44.94, 40.92, 71.32], [45.48, 40.95, 75.76], [46.06, 40.99, 81.97], [46.69, 41.04, 85.43], [47.34, 41.09, 83.73], [48.03, 41.14, 84.44], [48.73, 41.2, 87.21], [49.45, 41.25, 90.32], [50.19, 41.31, 93.75], [50.94, 41.36, 93.75], [51.69, 41.42, 97.93], [52.44, 41.5, 100.68], [53.19, 41.59, 102.54], [53.94, 41.71, 104.46], [54.68, 41.84, 106.12], [55.41, 41.99, 108.3]], (4, 46155.0): [[41.96, 17.69, 76.8], [42.06, 17.72, 82.31], [42.19, 17.76, 79.39], [42.36, 17.81, 78.25], [42.57, 17.89, 78.25], [42.82, 17.99, 77.62], [43.1, 18.12, 75.36], [43.42, 18.28, 73.96], [43.78, 18.47, 72.12], [44.16, 18.7, 71.07], [44.58, 18.97, 68.04], [45.01, 19.27, 68.04], [45.46, 19.61, 66.1], [45.92, 19.98, 62.16], [46.39, 20.37, 52.09], [46.87, 20.79, 44.41], [47.35, 21.22, 34.34], [47.84, 21.66, 18.43], [48.32, 22.09, 359.48], [48.8, 22.5, 338.3], [49.26, 22.9, 323.15], [49.71, 23.26, 313.1], [50.15, 23.6, 305.39], [50.56, 23.91, 299.86], [50.96, 24.21, 298.54], [51.33, 24.48, 295.52], [51.68, 24.75, 293.64], [52.02, 25.01, 292.74], [52.34, 25.25, 292.74]], (5, 47808.0): [[40.79, 15.12, 73.12], [40.8, 15.12, 74.78], [40.82, 15.12, 74.78], [40.89, 15.13, 73.96], [41.02, 15.13, 73.96], [41.23, 15.13, 74.92], [41.5, 15.13, 74.92], [41.82, 15.11, 71.32], [42.21, 15.11, 71.32], [42.67, 15.1, 73.51], [43.17, 15.08, 73.51], [43.72, 15.07, 72.67], [44.31, 15.05, 72.67], [44.93, 15.03, 74.17], [45.56, 15.01, 74.17], [46.22, 15.0, 71.52], [46.89, 14.98, 64.12], [47.57, 14.97, 61.42], [48.26, 14.97, 58.79], [48.95, 14.98, 54.25], [49.64, 15.02, 40.97], [50.34, 15.1, 39.13], [51.03, 15.19, 34.03], [51.72, 15.33, 25.4], [52.39, 15.5, 6.71], [53.05, 15.7, 356.21], [53.7, 15.95, 347.81], [54.31, 16.22, 343.86], [54.91, 16.53, 343.86]], (3, 47810.0): [[52.25, 17.87, 282.38], [52.5, 17.87, 280.03], [52.75, 17.88, 277.84], [53.02, 17.9, 276.43], [53.29, 17.95, 276.43], [53.56, 18.01, 276.43], [53.84, 18.1, 276.43], [54.12, 18.21, 276.43], [54.41, 18.34, 276.43], [54.7, 18.49, 276.43], [54.99, 18.66, 276.43], [55.29, 18.86, 279.41], [55.58, 19.08, 284.62], [55.88, 19.34, 285.66], [56.16, 19.62, 287.71], [56.44, 19.94, 288.77], [56.71, 20.28, 293.92], [56.96, 20.65, 301.97], [57.19, 21.05, 309.03], [57.37, 21.47, 312.43], [57.52, 21.91, 318.65], [57.64, 22.35, 320.9], [57.71, 22.8, 326.04], [57.71, 23.23, 329.06], [57.65, 23.65, 330.4], [57.52, 24.05, 328.54], [57.31, 24.43, 325.6], [57.04, 24.78, 320.02], [56.7, 25.11, 318.6]], (0, 47823.0): [[49.26, 12.72, 337.53], [49.32, 12.75, 334.26], [49.34, 12.76, 334.26], [49.37, 12.76, 333.18], [49.41, 12.75, 333.91], [49.51, 12.74, 337.42], [49.55, 12.73, 337.42], [49.6, 12.72, 334.45], [49.71, 12.69, 326.68], [49.88, 12.66, 322.8], [50.12, 12.62, 321.04], [50.41, 12.56, 319.13], [50.75, 12.51, 319.13], [51.13, 12.46, 316.98], [51.55, 12.42, 315.06], [51.99, 12.38, 314.04], [52.45, 12.35, 318.1], [52.92, 12.33, 323.26], [53.39, 12.33, 331.34], [53.88, 12.34, 337.23], [54.36, 12.38, 344.06], [54.86, 12.45, 3 ...
# (2021091300, 4765) {(0, 38592.0): [[50.11, 37.92, 245.96], [50.14, 37.93, 247.38], [50.17, 37.94, 250.68], [50.22, 37.95, 250.68], [50.28, 37.96, 250.68], [50.36, 37.97, 251.32], [50.47, 37.99, 251.32], [50.58, 38.0, 249.15], [50.72, 38.01, 246.37], [50.89, 38.01, 242.66], [51.09, 38.0, 237.77], [51.31, 37.98, 226.26], [51.56, 37.95, 218.49], [51.83, 37.9, 212.57], [52.13, 37.84, 208.46], [52.44, 37.77, 203.57], [52.78, 37.68, 199.98], [53.13, 37.59, 198.89], [53.5, 37.47, 196.11], [53.87, 37.35, 196.11], [54.24, 37.22, 196.11], [54.62, 37.08, 201.03], [54.99, 36.94, 207.63], [55.35, 36.79, 212.12], [55.69, 36.62, 216.29], [56.0, 36.45, 219.22], [56.28, 36.3, 220.21], [56.52, 36.14, 222.3], [56.73, 36.0, 224.64], [56.9, 35.85, 230.4], [57.03, 35.69, 228.57], [57.12, 35.54, 229.34], [57.17, 35.38, 229.96], [57.19, 35.2, 228.88], [57.17, 34.99, 231.26]], (5, 41230.0): [[41.93, 10.88, 100.38], [41.93, 10.88, 100.38], [41.94, 10.88, 99.31], [41.95, 10.87, 98.51], [41.98, 10.86, 98.51], [42.05, 10.83, 97.83], [42.15, 10.78, 94.26], [42.33, 10.69, 94.26], [42.56, 10.58, 94.26], [42.81, 10.46, 93.4], [43.12, 10.28, 94.44], [43.48, 10.09, 92.4], [43.87, 9.86, 88.95], [44.3, 9.62, 87.85], [44.76, 9.35, 88.76], [45.26, 9.06, 84.07], [45.78, 8.76, 76.5], [46.34, 8.45, 75.18], [46.92, 8.14, 71.2], [47.51, 7.83, 67.62], [48.12, 7.54, 65.92], [48.72, 7.26, 65.92], [49.32, 6.99, 65.17], [49.9, 6.74, 63.07], [50.47, 6.49, 62.16], [51.01, 6.25, 59.98], [51.54, 6.02, 62.29], [52.01, 5.78, 61.63], [52.46, 5.55, 52.27], [52.88, 5.33, 48.95], [53.28, 5.1, 45.33], [53.67, 4.89, 41.0], [54.03, 4.68, 38.68], [54.38, 4.48, 36.63], [54.72, 4.28, 38.75]], (4, 46155.0): [[41.81, 33.62, 102.53], [41.82, 33.62, 103.43], [41.85, 33.62, 102.63], [41.89, 33.62, 102.63], [42.06, 33.63, 101.1], [42.3, 33.62, 101.1], [42.55, 33.62, 101.1], [42.84, 33.62, 95.62], [43.17, 33.61, 92.14], [43.55, 33.6, 95.8], [43.98, 33.59, 95.8], [44.46, 33.58, 94.22], [44.99, 33.57, 93.55], [45.56, 33.56, 93.55], [46.15, 33.55, 95.51], [46.75, 33.53, 97.7], [47.37, 33.5, 97.7], [47.98, 33.44, 95.04], [48.58, 33.37, 103.09], [49.15, 33.29, 131.74], [49.71, 33.18, 145.84], [50.23, 33.06, 160.54], [50.74, 32.93, 176.89], [51.21, 32.78, 181.31], [51.65, 32.64, 184.35], [52.05, 32.51, 196.46], [52.38, 32.41, 203.04], [52.67, 32.33, 210.14], [52.93, 32.26, 217.9], [53.15, 32.22, 226.99], [53.33, 32.2, 234.87], [53.47, 32.21, 241.83], [53.59, 32.25, 247.31], [53.68, 32.32, 252.06], [53.76, 32.4, 255.66]], (5, 47808.0): [[41.49, 31.86, 82.89], [41.51, 31.86, 81.42], [41.55, 31.86, 81.42], [41.62, 31.84, 82.32], [41.77, 31.83, 86.3], [41.96, 31.8, 86.3], [42.21, 31.75, 85.45], [42.51, 31.68, 86.36], [42.87, 31.58, 88.15], [43.28, 31.44, 92.27], [43.75, 31.29, 92.27], [44.25, 31.1, 92.27], [44.8, 30.88, 93.13], [45.37, 30.64, 96.43], [45.97, 30.36, 99.8], [46.58, 30.05, 105.66], [47.19, 29.7, 110.56], [47.81, 29.31, 115.38], [48.44, 28.89, 118.39], [49.05, 28.42, 122.21], [49.65, 27.93, 126.87], [50.24, 27.39, 132.33], [50.81, 26.82, 137.14], [51.35, 26.22, 142.58], [51.86, 25.58, 147.59], [52.34, 24.92, 153.87], [52.79, 24.23, 155.48], [53.19, 23.52, 162.37], [53.55, 22.78, 171.1], [53.88, 22.04, 184.0], [54.18, 21.29, 191.69], [54.43, 20.53, 199.26], [54.66, 19.77, 206.85], [54.85, 19.0, 213.72], [55.01, 18.23, 217.45]], (3, 47810.0): [[51.48, 25.42, 327.81], [52.01, 25.4, 340.71], [52.55, 25.39, 347.93], [53.1, 25.4, 348.53], [53.66, 25.42, 343.84], [54.22, 25.45, 340.56], [54.78, 25.48, 337.72], [55.35, 25.51, 334.3], [55.91, 25.53, 329.0], [56.47, 25.55, 324.04], [57.04, 25.57, 319.82], [57.61, 25.58, 313.29], [58.17, 25.59, 305.75], [58.73, 25.59, 301.82], [59.29, 25.58, 296.82], [59.84, 25.56, 291.74], [60.4, 25.53, 283.89], [60.96, 25.49, 281.95], [61.51, 25.43, 279.84], [62.07, 25.36, 273.02], [62.62, 25.27, 269.17], [63.17, 25.16, 266.81], [63.72, 25.04, 268.65], [64.26, 24.9, 266.62], [64.8, 24.75, 265.44], [65.33, 24.59, 265.44], [65.86, 24.42, 265.44], [66.38, 24.23, 264.52], [ ...
# (2021091300, 2256) {(5, 41230.0): [[52.43, 31.07, 94.8], [52.44, 31.07, 93.55], [52.45, 31.06, 95.31], [52.48, 31.06, 97.44], [52.55, 31.04, 95.45], [52.69, 30.97, 94.18], [52.86, 30.89, 95.07], [53.12, 30.77, 99.94], [53.41, 30.64, 103.22], [53.76, 30.46, 103.22], [54.15, 30.27, 108.14], [54.57, 30.05, 113.91], [55.03, 29.82, 117.3], [55.52, 29.57, 120.07], [56.02, 29.31, 129.43], [56.51, 29.06, 138.95], [56.98, 28.81, 150.55], [57.43, 28.58, 164.34], [57.84, 28.35, 183.05], [58.22, 28.14, 194.82], [58.53, 27.93, 213.11], [58.78, 27.75, 228.99], [58.96, 27.59, 244.46], [59.09, 27.45, 255.72], [59.15, 27.33, 270.69], [59.17, 27.23, 276.51]], (4, 46155.0): [[52.44, 16.82, 78.07], [52.48, 16.82, 79.24], [52.56, 16.83, 82.78], [52.72, 16.83, 84.64], [52.92, 16.83, 85.37], [53.21, 16.81, 88.7], [53.53, 16.79, 88.7], [53.9, 16.77, 90.03], [54.32, 16.73, 89.0], [54.78, 16.68, 93.3], [55.29, 16.62, 94.64], [55.83, 16.55, 96.49], [56.41, 16.48, 96.49], [57.03, 16.4, 96.49], [57.67, 16.33, 96.49], [58.33, 16.25, 96.49], [59.01, 16.19, 91.48], [59.7, 16.13, 89.61], [60.41, 16.09, 88.42], [61.11, 16.07, 85.82], [61.83, 16.08, 79.43], [62.54, 16.11, 74.72], [63.25, 16.19, 70.45], [63.95, 16.3, 63.15], [64.64, 16.46, 53.15], [65.32, 16.64, 46.14]], (5, 47808.0): [[51.76, 35.91, 86.9], [51.76, 35.91, 87.99], [51.77, 35.91, 88.67], [51.81, 35.91, 87.84], [51.87, 35.91, 89.65], [51.98, 35.91, 89.65], [52.15, 35.93, 86.78], [52.38, 35.96, 82.02], [52.66, 35.99, 79.61], [53.01, 36.04, 76.91], [53.4, 36.1, 72.09], [53.84, 36.17, 72.09], [54.33, 36.28, 67.07], [54.86, 36.42, 64.12], [55.42, 36.59, 60.26], [56.01, 36.79, 55.75], [56.61, 37.03, 51.31], [57.22, 37.3, 49.95], [57.84, 37.6, 47.97], [58.46, 37.91, 46.54], [59.07, 38.23, 48.07], [59.69, 38.55, 51.98], [60.29, 38.87, 57.29], [60.87, 39.16, 63.41], [61.44, 39.44, 66.74], [61.98, 39.69, 86.05]], (3, 47810.0): [[58.83, 10.41, 301.98], [58.83, 10.41, 301.17], [58.84, 10.41, 301.17], [58.84, 10.4, 300.53], [58.85, 10.4, 300.53], [58.87, 10.39, 296.55], [58.89, 10.39, 295.85], [58.91, 10.38, 292.46], [58.96, 10.36, 283.01], [59.06, 10.32, 279.94], [59.21, 10.28, 277.17], [59.4, 10.21, 272.45], [59.63, 10.13, 267.28], [59.87, 10.05, 260.64], [60.14, 9.96, 254.79], [60.41, 9.87, 249.76], [60.65, 9.79, 249.76], [60.86, 9.71, 246.93], [61.04, 9.64, 246.93], [61.17, 9.58, 244.59], [61.24, 9.51, 248.6], [61.27, 9.44, 250.76], [61.26, 9.38, 252.53], [61.2, 9.31, 260.17], [61.12, 9.25, 265.29], [61.02, 9.22, 274.25]], (0, 47823.0): [[60.51, 15.45, 343.26], [60.51, 15.46, 341.89], [60.53, 15.48, 341.09], [60.55, 15.48, 342.5], [60.57, 15.49, 341.72], [60.6, 15.49, 339.82], [60.67, 15.5, 337.15], [60.79, 15.51, 334.35], [60.96, 15.52, 329.08], [61.17, 15.53, 326.46], [61.42, 15.54, 321.63], [61.71, 15.54, 317.19], [62.03, 15.53, 310.2], [62.37, 15.52, 305.26], [62.72, 15.5, 298.63], [63.08, 15.48, 290.88], [63.45, 15.47, 287.69], [63.82, 15.45, 280.54], [64.19, 15.45, 276.14], [64.55, 15.47, 273.69], [64.89, 15.51, 273.69], [65.22, 15.57, 277.52], [65.54, 15.66, 283.12], [65.86, 15.77, 288.95], [66.18, 15.91, 299.43], [66.51, 16.06, 309.82]], (2, 53472.0): [[69.87, 31.44, 231.25], [69.91, 31.42, 231.25], [69.94, 31.41, 230.27], [69.98, 31.41, 228.75], [70.03, 31.41, 229.88], [70.07, 31.41, 227.87], [70.13, 31.41, 225.95], [70.23, 31.41, 233.5], [70.38, 31.43, 237.9], [70.58, 31.45, 240.49], [70.81, 31.47, 244.4], [71.07, 31.49, 252.78], [71.36, 31.52, 259.1], [71.68, 31.54, 259.87], [72.02, 31.57, 256.72], [72.39, 31.58, 258.85], [72.78, 31.59, 256.0], [73.19, 31.6, 249.23], [73.61, 31.6, 248.45], [74.04, 31.6, 247.42], [74.46, 31.59, 249.37], [74.88, 31.58, 245.21], [75.29, 31.57, 243.12], [75.68, 31.56, 243.12], [76.05, 31.55, 243.12], [76.38, 31.54, 250.27]], (5, 52500.0): [[51.27, 45.53, 63.3], [51.29, 45.53, 73.72], [51.34, 45.54, 76.1], [51.42, 45.55, 73.88], [51.56, 45.59, 67.16], [51.76, 45.64, 64.64], [52.0, 45.7, 60.95], [52.3, 45.76, 51.37], [52.65, 45.84, 49.01], [53.04, 45.92, 49.72], [53.4 ...

# %% [markdown]
# ### Printing Captured Events

# %%
event_dic = category_codes["event"]
event_dic_keyarr = list(event_dic.keys())
event_dic_valuearr = list(event_dic.values())
for event in captured_events:
    print(event_dic_keyarr[event_dic_valuearr.index(event)])
# Out:
# ball_snap
# autoevent_passforward
# pass_forward
# play_action
# autoevent_passinterrupted
# autoevent_ballsnap
# man_in_motion
# shift
# first_contact
# handoff
# line_set
# dropped_pass
# penalty_flag
# huddle_break_offense

# %% [markdown]
# ### Displaying Distribution Of Play Length After Ball Snap

# %%
player_tracking_isolated_sum = player_tracking_isolated.groupby(["gameId","playId","nflId"]).size().reset_index(name="counts")
display(player_tracking_isolated_sum)

seq_play_list = player_tracking_isolated_sum["counts"].array

seq_play_df = pd.DataFrame(seq_play_list,columns=["Play Length"])
sb.displot(seq_play_df,x="Play Length",height=10,aspect=2)
# Out:
#            gameId  playId    nflId  counts
# 0      2021090900      97  35481.0      43
# 1      2021090900      97  35634.0      43
# 2      2021090900      97  41233.0      43
# 3      2021090900      97  43478.0      43
# 4      2021090900      97  44896.0      43
# ...           ...     ...      ...     ...
# 76836  2021110100    4433  47954.0      58
# 76837  2021110100    4433  47984.0      58
# 76838  2021110100    4433  52546.0      58
# 76839  2021110100    4433  52573.0      58
# 76840  2021110100    4433  53449.0      58
#
# [76841 rows x 4 columns]

# %% [markdown]
# ### Displaying Distribution of Events After Ball Snap

# %%
events = player_tracking_isolated.loc[(player_tracking_isolated["event"] != 0)]
events["event"] = events["event"].apply(lambda x:event_dic_keyarr[event_dic_valuearr.index(x)]) 

sb.displot(events,x="event",height=10,aspect=2)
plt.xticks(rotation = 55)
plt.show()
# Out:
# C:\Users\Alejo\AppData\Local\Temp\ipykernel_8244\3429099777.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   events["event"] = events["event"].apply(lambda x:event_dic_keyarr[event_dic_valuearr.index(x)])

# %% [markdown]
# ### Getting Player Information To Identify Offensive and Defensive Pairs

# %%
player_info = player_tracking_isolated[["nflId","gameId","playId","officialPosition"]]
player_info.drop_duplicates(inplace=True)
display(player_info)
# Out:
# C:\Users\Alejo\AppData\Local\Temp\ipykernel_8244\3124698956.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_info.drop_duplicates(inplace=True)
#            nflId      gameId  playId  officialPosition
# 0        35481.0  2021090900      97                 4
# 43       35481.0  2021090900     410                 4
# 70       35481.0  2021090900     434                 4
# 98       35481.0  2021090900     456                 4
# 134      35481.0  2021090900     480                 4
# ...          ...         ...     ...               ...
# 3245456  53500.0  2021110100     775                 0
# 3245498  53500.0  2021110100     797                 0
# 3245547  53500.0  2021110100    1160                 0
# 3245583  53500.0  2021110100    1182                 0
# 3245669  53500.0  2021110100    1480                 0
#
# [76841 rows x 4 columns]

# %% [markdown]
# ### Identifying Pairs Of Offensive and Defensive Players

# %%
offensive_positions = [5] #TE,WR = 5
defensive_positions = [1,3,2,0]#SS,FS,CB (DB INCLUDED)

# %% [markdown]
# ### Create A Function For Checking The Euclidean Distance Between Player Points

# %%
def euclidean_distance(first_x,first_y,second_x,second_y):
    return math.sqrt(((first_x-second_x)**2)+((first_y-second_y)**2))

# %%
def flipX(x,los_x):
    flipped_x = x - los_x
    flipped_x = -flipped_x
    flipped_x = flipped_x+los_x
    return flipped_x

def flipY(y,los_y):
    flipped_y = y - los_y
    flipped_y = -flipped_y
    flipped_y = flipped_y+los_y
    return flipped_y

# %% [markdown]
# ### Isolating Player Pairs Into A Dictionary

# %%
player_pairs = {}
player_pair_sequences = []
player_pair_sequences_sorted = []
o_player_sequences = []
d_player_sequences = []
o_player_sequences_id = []
player_pair_ids = {}

los_y = 26.65
left_sideline = 53.3
right_sideline = 0.0
los_x = -1
for first_key in seq_dict:
    valid_inner_id = player_info.loc[(player_info["gameId"]==first_key[0])&(player_info["playId"]==first_key[1])]
    offensive_players = valid_inner_id.loc[(valid_inner_id["officialPosition"].isin(offensive_positions))]
    defensive_players = valid_inner_id.loc[(valid_inner_id["officialPosition"].isin(defensive_positions))]
    current_play = player_tracking_isolated.loc[(player_tracking_isolated["gameId"]==first_key[0])&(player_tracking_isolated["playId"]==first_key[1])]
    current_play = current_play.iloc[0]

    play_direction = current_play['playDirection']
    flip_x = play_direction == 0
    #print(play_direction)
    mask = (ball_first_frame['gameId'] == first_key[0])&(ball_first_frame["playId"]==first_key[1])
    ball_row = ball_first_frame[mask]
    if ball_row.empty:
        los_x = -1
    else:
        los_x = ball_row.iloc[0]['x']
    play_dict = seq_dict[first_key]
    play_dict_dense = seq_dict_dense[first_key]
    play_pairs = []
    player_pair_ids[first_key] = []
    for o_player_row in offensive_players.itertuples():
        o_player_key = (o_player_row.officialPosition,o_player_row.nflId)
        if o_player_key in play_dict:
            offensive_player_seq = play_dict[o_player_key]
            min_distance_id = (-1,-1)
            min_distance = -1
            d_player_min_row = -1
            for d_player_row in defensive_players.itertuples():
                d_player_key = (d_player_row.officialPosition,d_player_row.nflId)
                if d_player_key in play_dict:
                    defensive_player_seq = play_dict[d_player_key]
                    o_length = len(offensive_player_seq)
                    d_length = len(defensive_player_seq)
                    min_length = min(o_length,d_length)
                    num_points = min(10,min_length)
                    current_distance = 10000
                    for i in range(num_points):
                        current_index = int(min_length*0.1*i)
                        o_point = offensive_player_seq[current_index]
                        d_point = defensive_player_seq[current_index]
                        distance = math.dist([o_point[2],o_point[3]],[d_point[2],d_point[3]])
                        if distance > current_distance or current_distance == 10000:
                            current_distance = distance
                    last_o_point = offensive_player_seq[-1]
                    last_d_point = defensive_player_seq[-1]
                    distance = math.dist([last_o_point[2],last_o_point[3]],[last_d_point[2],last_d_point[3]])
                    if distance > current_distance:
                        current_distance = distance
                    #mid_point = min(o_length//2,d_length//2)
                    #end_point = min(o_length-1,d_length-1)
                    #o_first_point = offensive_player_seq[1]
                    #d_first_point = defensive_player_seq[1]
                    #o_second_point = offensive_player_seq[mid_point]
                    #d_second_point = defensive_player_seq[mid_point]
                    #o_third_point = offensive_player_seq[end_point]
                    #d_third_point = offensive_player_seq[end_point]

                    #current_distance = math.dist([o_first_point[2],o_first_point[3]],[d_first_point[2],d_first_point[3]]) + math.dist([o_second_point[2],o_second_point[3]],[d_second_point[2],d_second_point[3]])+ math.dist([o_third_point[2],o_third_point[3]],[d_third_point[2],d_third_point[3]]) # 2 = x, 3 = y
                    if current_distance < min_distance or min_distance == -1:
                        min_distance = current_distance
                        min_distance_id = d_player_key
                        d_player_min_row = d_player_row
            if min_distance_id == (-1,-1):
                continue
            play_pairs.append((o_player_key,min_distance_id))
            if los_x != -1:
                o_player_sequence = play_dict_dense[o_player_key]
                d_player_seq = play_dict_dense[min_distance_id]

                original_o_start_x = o_player_sequence[0][0]
                original_o_start_y = o_player_sequence[0][1]
                #original_d_start_x = d_player_seq[0][0]
                #original_d_start_y = d_player_seq[0][1]
                flip_y = original_o_start_y > los_y
                #flip_x = play_direction == 0
                o_left_sideline_distance = abs(left_sideline - original_o_start_y)
                o_right_sideline_distance = abs(original_o_start_y)
                if flip_x:
                    # original play is moving left
                    o_player_sequence = [[flipX(x[0],los_x),x[1],x[2]] for x in o_player_sequence]
                    d_player_seq = [[flipX(x[0],los_x),x[1],x[2]] for x in d_player_seq]
                    endzone_distance = abs(original_o_start_x)
                else:
                    endzone_distance = abs(120-original_o_start_x)
                if flip_y:
                    o_player_sequence = [[x[0],flipY(x[1],los_y),x[2]] for x in o_player_sequence]
                    d_player_seq = [[x[0],flipY(x[1],los_y),x[2]] for x in d_player_seq]
                o_start_x = o_player_sequence[0][0]
                o_start_y = o_player_sequence[0][1]
                d_start_x = d_player_seq[0][0]-o_start_x
                d_start_y = d_player_seq[0][1]-o_start_y
                if d_start_x< 0:
                    print(f"X Normalization failed. Value received is {d_start_x}")
                    continue
                #d_left_sideline_distance = abs(left_sideline - d_start_y)
                #d_right_sideline_distance = abs(right_sideline-d_start_y)


                d_player_seq_modified = [[x[0]-o_start_x,x[1]-o_start_y,x[2]] for x in d_player_seq]
                o_player_seq_modified = [[x[0]-o_start_x,x[1]-o_start_y,x[2], d_start_x, d_start_y,los_x,o_left_sideline_distance,o_right_sideline_distance,endzone_distance] for x in o_player_sequence]
                # = [[x[0]-o_start_x,x[1]-o_start_y,x[2],x[3],x[4],x[5], d_start_x, d_start_y,d_left_sideline_distance,d_right_sideline_distance,o_left_sideline_distance,o_right_sideline_distance,los_x] for x in o_player_sequence]
                if min_distance < 8:
                    player_pair_ids[first_key].append(len(o_player_sequences))
                    o_player_sequences.append(o_player_seq_modified)
                    d_player_sequences.append(d_player_seq_modified)
                    o_player_sequences_id.append((first_key[0],first_key[1],o_player_key[1],min_distance_id[1]))
                sequence_pair = [o_player_seq_modified,d_player_seq_modified]
                player_pair_sequences.append(sequence_pair)
                if min_distance!= -1:
                    player_pair_sequences_sorted.append((min_distance,sequence_pair))
    player_pairs[first_key] = play_pairs

print(f"Created player pairs for {len(player_pairs)} different plays")
sum = 0
for key in player_pairs:
    sum+= len(player_pairs[key])
print(f"Player Pairs Generated: {sum}")
print(f"Valid player Sequence Pairs: {len(player_pair_sequences)}")
player_pair_sequences_sorted = sorted(player_pair_sequences_sorted,key=lambda x:x[0])
#player_pair_sequences_filtered = list(filter(lambda x:x[0]<15,player_pair_sequences_sorted))
#print(f"Filtered Sequence Pairs: {len(player_pair_sequences_filtered)}")
# Out:
# X Normalization failed. Value received is -10.88000000000001
# X Normalization failed. Value received is -3.8000000000000043
# X Normalization failed. Value received is -38.3
# X Normalization failed. Value received is -5.840000000000032
# X Normalization failed. Value received is -9.180000000000007
# X Normalization failed. Value received is -23.760000000000005
# X Normalization failed. Value received is -40.2
# X Normalization failed. Value received is -5.469999999999999
# X Normalization failed. Value received is -49.739999999999995
# X Normalization failed. Value received is -50.58
# Created player pairs for 8522 different plays
# Player Pairs Generated: 22983
# Valid player Sequence Pairs: 22973

# %%
print(f"Number of Offensive Sequences: {len(o_player_sequences)}")
print(f"Number of Defensive Sequences: {len(d_player_sequences)}")
# Out:
# Number of Offensive Sequences: 13276
# Number of Defensive Sequences: 13276

# %% [markdown]
# ### Generating Plot For Every Player On a Given Play With No Position Filters
#
# First we will encode data that is not filtered by player positions using one hot encoding. This is a repetition of what we initially did with the position filtered data above.

# %%
tracking_copy = tracking_w1_data.copy()
tracking_copy = tracking_copy.merge(player_positions,how="inner",on="nflId")
categorical_data = ["team","playDirection","event","officialPosition"]
category_codes_all = {}

w1_data_copy = tracking_copy.copy()

for i in tracking_copy:
    if i in categorical_data:
        specific_codes = {}
        tracking_copy[i] = tracking_copy[i].astype("category")
        tracking_copy[i] = tracking_copy[i].cat.codes
        coded = tracking_copy[i].unique()#
        count = 0
        for j in w1_data_copy[i].unique():
           specific_codes[j] = coded[count]
           count += 1
        category_codes_all[i] = specific_codes
for i in category_codes_all:
  print("{} -".format(i))
  for j in category_codes_all[i]:
    print("{}: {}".format(j, category_codes_all[i][j]))
# Out:
# team -
# TB: 29
# DAL: 8
# GB: 11
# ATL: 1
# PHI: 25
# ARI: 0
# PIT: 26
# BUF: 3
# LA: 16
# NYJ: 24
# CAR: 4
# JAX: 14
# MIN: 20
# CIN: 6
# DEN: 9
# SF: 28
# DET: 10
# NE: 21
# HOU: 12
# NO: 22
# SEA: 27
# IND: 13
# TEN: 30
# LAC: 17
# WAS: 31
# CLE: 7
# KC: 15
# MIA: 19
# CHI: 5
# LV: 18
# NYG: 23
# BAL: 2
# playDirection -
# right: 1
# left: 0
# event -
# None: 0
# ball_snap: 4
# autoevent_passforward: 2
# pass_forward: 16
# pass_arrived: 15
# play_action: 21
# autoevent_passinterrupted: 3
# autoevent_ballsnap: 1
# man_in_motion: 13
# pass_outcome_caught: 17
# shift: 25
# qb_strip_sack: 23
# pass_outcome_incomplete: 18
# pass_tipped: 19
# run: 24
# qb_sack: 22
# fumble_offense_recovered: 8
# tackle: 26
# line_set: 12
# fumble: 7
# handoff: 9
# first_contact: 6
# out_of_bounds: 14
# dropped_pass: 5
# penalty_flag: 20
# huddle_break_offense: 10
# lateral: 11
# officialPosition -
# QB: 13
# TE: 17
# WR: 18
# RB: 14
# C: 0
# DE: 3
# T: 16
# G: 7
# MLB: 10
# CB: 1
# SS: 15
# OLB: 12
# DT: 4
# ILB: 8
# NT: 11
# FS: 6
# FB: 5
# LB: 9
# DB: 2

# %% [markdown]
# ### Plot Play Function
#
# Here we generate sequences for a single demo play and plot the player sequences generated for that play. Red corresponds to the offensive team while Blue is the defensive team.

# %%
def plot_play(demo_key):
    demo_play_df_all_positions = tracking_copy.loc[(tracking_copy["gameId"]==demo_key[0])&(tracking_copy["playId"] ==demo_key[1])]
    #display(demo_play_df_all_positions)
    play_ids = demo_play_df_all_positions[["nflId","team","officialPosition"]].drop_duplicates()
    play_sequences_dict = generate_sequences_single_play(demo_play_df_all_positions)

    figure = plt.figure(figsize=(20,10))
    print(f"----------------------------- Displaying Player Tracking Sequences From Play With (gameId,playId)): {demo_key} -----------------------------")
    print("\n\n Here, defense is in blue and offense is in red. \n\n")
    team = -1
    defensive_team = play_data.loc[(play_data["gameId"] == demo_key[0])&(play_data["playId"]==demo_key[1])]
    defensive_team = defensive_team.iloc[0]["defensiveTeam"]
    defensive_team = category_codes["team"][defensive_team]
    play_direction = "right" if demo_play_df_all_positions.iloc[0]["playDirection"] == 1 else "left"
    print(f"Play Direction: {play_direction}\n\n")
    #print(defensive_team)
    for id in play_ids.itertuples():
        id_tuple = (id.officialPosition,id.nflId)
        if id_tuple in play_sequences_dict:
            player_x = []
            player_y = []
            player_seq = play_sequences_dict[id_tuple]
            for point in player_seq:
                player_x.append(point[2])
                player_y.append(point[3])
            if len(player_x)>0 and len(player_y)>0:
                if id.team == defensive_team:
                    plt.plot(player_x,player_y,color = "b",zorder = 2)
                    plt.scatter(player_x[2],player_y[3],color="b",zorder =3)
                else:
                    plt.plot(player_x,player_y,color = "r",zorder = 2)
                    plt.scatter(player_x[2],player_y[3],color="r",zorder =3)

    #plt.ylim([0, 53.3])
    #plt.xlim([0, 120])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()

    plt.show()

# %% [markdown]
# ### Allowing Users to Select A Demo Play

# %%
player_pair_keys = list(player_pairs.keys())
input_index= int(input(f"Please enter a value between 0 and {len(player_pair_keys)-1} to select a demo play\n"))
demo_key = player_pair_keys[input_index]

plot_play(demo_key)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Alejo\OneDrive\Documents\CPSC502\CPSC502\Notebooks\lstm_related\ProcessSeqData.ipynb Cell 83 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Alejo/OneDrive/Documents/CPSC502/CPSC502/Notebooks/lstm_related/ProcessSeqData.ipynb#Y145sZmlsZQ%3D%3D?line=0'>1</a> player_pair_keys = list(player_pairs.keys())
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Alejo/OneDrive/Documents/CPSC502/CPSC502/Notebooks/lstm_related/ProcessSeqData.ipynb#Y145sZmlsZQ%3D%3D?line=1'>2</a> input_index= int(input(f"Please enter a value between 0 and {len(player_pair_keys)-1} to select a demo play\n"))
#       <a href='vscode-notebook-cell:/c%3A/Users/Alejo/OneDrive/Documents/CPSC502/CPSC502/Notebooks/lstm_related/ProcessSeqData.ipynb#Y145sZmlsZQ%3D%3D?line=2'>3</a> demo_key = player_pair_keys[input_index]
#       <a href='vscode-notebook-cell:/c%3A/Users/Alejo/OneDrive/Documents/CPSC502/CPSC502/Notebooks/lstm_related/ProcessSeqData.ipynb#Y145sZmlsZQ%3D%3D?line=4'>5</a> plot_play(demo_key)
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ### Plotting Player Pair Detected
# Here we plot the trajectories that were mapped as closest by the above pair detection. Here we can see that a closer line was not detected, which may be a result of the positional filters set on the data for the player pair detection.

# %%
input_index= int(input(f"Please enter a value between 0 and {len(player_pair_keys)-1} to select a demo play\n"))
demo_key = player_pair_keys[input_index]
input_inner_index = int(input(f"Please enter a value between 0 and {len(player_pairs[demo_key])} to select a player pair to plot in this play\n"))

demo_inner_key = player_pairs[demo_key][input_inner_index]
print(f"Plotting pair at input index {input_inner_index} for the play with keys: {demo_key} and {demo_inner_key}")

o_player_key = demo_inner_key[0]
d_player_key = demo_inner_key[1]
o_player_seq = seq_dict[demo_key][o_player_key]
d_player_seq = seq_dict[demo_key][d_player_key]
#o_player_seq = trajectory_standardization(seq_dict[demo_key][o_player_key])
#d_player_seq = trajectory_standardization(seq_dict[demo_key][d_player_key])

#print(o_player_seq)
o_player_x = []
o_player_y = []
d_player_x = []
d_player_y = []
#temp = []
for point in o_player_seq:
    #temp.append([point[0],point[1]])
    o_player_x.append(point[2])
    o_player_y.append(point[3])
for point in d_player_seq:
    d_player_x.append(point[2])
    d_player_y.append(point[3])
#print(temp)
figure = plt.figure(figsize=(20,10))
plt.scatter(o_player_x[0],o_player_y[0],color="r")
plt.plot(o_player_x,o_player_y,color = "r",label="Offensive Player")
plt.scatter(d_player_x[0],d_player_y[0],color="b")
plt.plot(d_player_x,d_player_y,color = "b",label="Defensive Player")
print(d_player_y)
#plt.ylim([0, 53.3])
#plt.xlim([0, 120])
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Plotting pair at input index 0 for the play with keys: (2021090900, 97) and ((5, 35634.0), (0, 43478.0))
# [37.62, 37.64, 37.64, 37.65, 37.69, 37.74, 37.83, 37.94, 38.1, 38.32, 38.55, 38.81, 39.08, 39.38, 39.68, 39.98, 40.28, 40.58, 40.86, 41.13, 41.39, 41.63, 41.83, 42.02, 42.2, 42.4, 42.59, 42.78, 42.89, 43.02, 43.06, 43.1, 42.98, 42.91, 42.82, 42.7, 42.28, 41.96]

# %% [markdown]
# ### Viewing Pair Sequences Sorted By The Shortest Distance Between Player Pairs

# %%
while True:
    input_index = int(input(f"Please enter a value between 0 and {len(player_pair_sequences_sorted)-1} to select a demo play\n"))
    player_pair_sequence = player_pair_sequences[input_index]
    o_player_seq = player_pair_sequence[0]
    d_player_seq = player_pair_sequence[1]
    #print(f"Metric: {player_pair_sequences[input_index][0]}")
    print(f"Index: {input_index}")
    #print(o_player_seq)
    
    #o_player_seq = trajectory_standardization(seq_dict[demo_key][o_player_key])
    #d_player_seq = trajectory_standardization(seq_dict[demo_key][d_player_key])

    #print(o_player_seq)
    o_player_x = []
    o_player_y = []
    d_player_x = []
    d_player_y = []
    #temp = []
    for point in o_player_seq:
        #temp.append([point[0],point[1]])
        o_player_x.append(point[0])
        o_player_y.append(point[1])
    for point in d_player_seq:
        d_player_x.append(point[0])
        d_player_y.append(point[1])
    #print(temp)
    figure = plt.figure(figsize=(20,10))
    plt.scatter(o_player_x[0],o_player_y[0],color="r")
    plt.plot(o_player_x,o_player_y,color = "r",label="Offensive Player")
    plt.scatter(d_player_x[0],d_player_y[0],color="b")
    plt.plot(d_player_x,d_player_y,color = "b",label="Defensive Player")
    #print(o_player_seq)
    #plt.ylim([-53.3, 53.3])
    #plt.xlim([-120, 120])
    plt.xlabel('x')
    plt.ylabel('y')
    plt.legend()
    plt.show()
# Out:
# Index: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Alejo\OneDrive\Documents\CPSC502\CPSC502\Notebooks\ProcessSeqData.ipynb Cell 72 in 2
#       <a href='vscode-notebook-cell:/c%3A/Users/Alejo/OneDrive/Documents/CPSC502/CPSC502/Notebooks/ProcessSeqData.ipynb#Y131sZmlsZQ%3D%3D?line=0'>1</a> while True:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Alejo/OneDrive/Documents/CPSC502/CPSC502/Notebooks/ProcessSeqData.ipynb#Y131sZmlsZQ%3D%3D?line=1'>2</a>     input_index = int(input(f"Please enter a value between 0 and {len(player_pair_sequences_sorted)-1} to select a demo play\n"))
#       <a href='vscode-notebook-cell:/c%3A/Users/Alejo/OneDrive/Documents/CPSC502/CPSC502/Notebooks/ProcessSeqData.ipynb#Y131sZmlsZQ%3D%3D?line=2'>3</a>     player_pair_sequence = player_pair_sequences[input_index]
#       <a href='vscode-notebook-cell:/c%3A/Users/Alejo/OneDrive/Documents/CPSC502/CPSC502/Notebooks/ProcessSeqData.ipynb#Y131sZmlsZQ%3D%3D?line=3'>4</a>     o_player_seq = player_pair_sequence[0]
#
# ValueError: invalid literal for int() with base 10: ''

# %%
'''input_inner_index = int(input(f"Please enter a value between 0 and {len(player_pairs[demo_key])} to select a standardized player pair to plot in this play\n"))
demo_inner_key = player_pairs[demo_key][input_inner_index]
print(f"Plotting pair at input index {input_inner_index} for the play with keys: {demo_key} and {demo_inner_key}")

o_player_key = demo_inner_key[0]
d_player_key = demo_inner_key[1]
o_player_seq = seq_dict_standardized[demo_key][o_player_key]
d_player_seq = seq_dict_standardized[demo_key][d_player_key]

o_player_x = []
o_player_y = []
d_player_x = []
d_player_y = []
for point in o_player_seq:
    o_player_x.append(point[2])
    o_player_y.append(point[3])
for point in d_player_seq:
    d_player_x.append(point[2])
    d_player_y.append(point[3])
    
figure = plt.figure(figsize=(20,10))
plt.scatter(o_player_x[0],o_player_y[0],color="r")
plt.plot(o_player_x,o_player_y,color = "r",label="Offensive Player")
plt.scatter(d_player_x[0],d_player_y[0],color="b")
plt.plot(d_player_x,d_player_y,color = "b",label="Defensive Player")
plt.ylim([-53.3, 53.3])
plt.xlim([-120, 120])
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
'''
# Out:
# 'input_inner_index = int(input(f"Please enter a value between 0 and {len(player_pairs[demo_key])} to select a standardized player pair to plot in this play\n"))\ndemo_inner_key = player_pairs[demo_key][input_inner_index]\nprint(f"Plotting pair at input index {input_inner_index} for the play with keys: {demo_key} and {demo_inner_key}")\n\no_player_key = demo_inner_key[0]\nd_player_key = demo_inner_key[1]\no_player_seq = seq_dict_standardized[demo_key][o_player_key]\nd_player_seq = seq_dict_standardized[demo_key][d_player_key]\n\no_player_x = []\no_player_y = []\nd_player_x = []\nd_player_y = []\nfor point in o_player_seq:\n    o_player_x.append(point[2])\n    o_player_y.append(point[3])\nfor point in d_player_seq:\n    d_player_x.append(point[2])\n    d_player_y.append(point[3])\n    \nfigure = plt.figure(figsize=(20,10))\nplt.scatter(o_player_x[0],o_player_y[0],color="r")\nplt.plot(o_player_x,o_player_y,color = "r",label="Offensive Player")\nplt.scatter(d_player_x[0],d_player_y[0],color="b")\nplt.plot(d_player_x,d_player_y,color = "b",label="Defensive Player")\nplt.ylim([-53.3, 53.3])\nplt.xlim([-120, 120])\nplt.xlabel(\'x\')\nplt.ylabel(\'y\')\nplt.legend()\nplt.show()\n'

# %% [markdown]
# ### Repeating Player Pair Detection With No Position Filter On the Data'
#
# Here we repeat the same code as above to generate sequences for all the data without any positional filters

# %%
_,_,seq_dict_all_positions,_ = generate_sequences(tracking_copy)
offensive_positions = [11,15,16,12,0,14,6,4] #TE,WR
defensive_positions = [2,8,1,13,10,3,7,9,5]#SS,FS,CB (DB NOT INCLUDED)

#print(seq_dict_all_positions[(2021090900, 97)])
player_info = tracking_copy[["nflId","gameId","playId","officialPosition"]]
player_info.drop_duplicates(inplace=True)
display(player_info)


all_player_pairs = {}
for first_key in seq_dict_all_positions:
    #print(first_key)
    valid_inner_id = player_info.loc[(player_info["gameId"]==first_key[0])&(player_info["playId"]==first_key[1])]
    offensive_players = valid_inner_id.loc[(valid_inner_id["officialPosition"].isin(offensive_positions))]
    defensive_players = valid_inner_id.loc[(valid_inner_id["officialPosition"].isin(defensive_positions))]
    play_dict = seq_dict_all_positions[first_key]
    play_pairs = []
    for o_player_row in offensive_players.itertuples():
        o_player_key = (o_player_row.officialPosition,o_player_row.nflId)
        if o_player_key in play_dict:
            offensive_player_seq = play_dict[o_player_key]
            min_distance_id = (-1,-1)
            min_distance = -1
            #print(f"Offensive player: {o_player_key}")
            for d_player_row in defensive_players.itertuples():
                d_player_key = (d_player_row.officialPosition,d_player_row.nflId)
                if d_player_key in play_dict:
                    defensive_player_seq = play_dict[d_player_key]
                    o_length = len(offensive_player_seq)
                    d_length = len(defensive_player_seq)
                    mid_point = min(o_length//2,d_length//2)
                    end_point = min(o_length-1,d_length-1)
                    o_first_point = offensive_player_seq[1]
                    d_first_point = defensive_player_seq[1]
                    o_second_point = offensive_player_seq[mid_point]
                    d_second_point = defensive_player_seq[mid_point]
                    o_third_point = offensive_player_seq[end_point]
                    d_third_point = offensive_player_seq[end_point]
                    current_distance = math.dist([o_first_point[0],o_first_point[1]],[d_first_point[0],d_first_point[1]]) + math.dist([o_second_point[0],o_second_point[1]],[d_second_point[0],d_second_point[1]])+ math.dist([o_third_point[0],o_third_point[1]],[d_third_point[0],d_third_point[1]]) # 2 = x, 3 = y
                    
                    #print(f"Current min: {min_distance}")
                    #print(f"Defensive player: {d_player_key} with distance: {current_distance}")
                    
                    if current_distance < min_distance or min_distance == -1:
                        min_distance = current_distance
                        min_distance_id = d_player_key
            play_pairs.append((o_player_key,min_distance_id))
    all_player_pairs[first_key] = play_pairs 
    #break

print(f"Created player pairs for {len(all_player_pairs)} different plays")
sum = 0
for key in all_player_pairs:
    sum+= len(all_player_pairs[key])
print(f"Player Pairs Generated: {sum}")
# Out:
# Sequences generated: 187483
# C:\Users\Alejo\AppData\Local\Temp\ipykernel_3520\3847876655.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   player_info.drop_duplicates(inplace=True)
#            nflId      gameId  playId  officialPosition
# 0        25511.0  2021090900      97                13
# 43       25511.0  2021090900     410                13
# 70       25511.0  2021090900     434                13
# 98       25511.0  2021090900     456                13
# 134      25511.0  2021090900     480                13
# ...          ...         ...     ...               ...
# 7952438  46772.0  2021110100    1351                12
# 7952487  46772.0  2021110100    1396                12
# 7952539  46772.0  2021110100    1458                12
# 7952574  46772.0  2021110100    3392                12
# 7952612  46772.0  2021110100    3471                12
#
# [188254 rows x 4 columns]
# Created player pairs for 8522 different plays
# Player Pairs Generated: 79625

# %% [markdown]
# ### Plotting The New Player Pairs
#
# Here we repeat the plot seen above with the player pairs without positional filters.

# %%
demo_inner_key = -1
for key in all_player_pairs:
    demo_key = key
    demo_inner_key = all_player_pairs[key][1]
    print(f"Outer Key: {key}")
    print(f"Inner Key: {demo_inner_key}")
    break
o_player_key = demo_inner_key[0]
d_player_key = demo_inner_key[1]
o_player_seq = seq_dict_all_positions[demo_key][o_player_key]
d_player_seq = seq_dict_all_positions[demo_key][d_player_key]


o_player_x = []
o_player_y = []
d_player_x = []
d_player_y = []

for point in o_player_seq:
    o_player_x.append(point[2])
    o_player_y.append(point[3])
for point in d_player_seq:
    d_player_x.append(point[2])
    d_player_y.append(point[3])

figure = plt.figure(figsize=(20,10))
plt.scatter(o_player_x[0],o_player_y[0],color="r")
plt.plot(o_player_x,o_player_y,color = "r",label="Offensive Player")
plt.scatter(d_player_x[0],d_player_y[0],color="b")
plt.plot(d_player_x,d_player_y,color = "b",label="Defensive Player")
plt.ylim([0, 53.3])
plt.xlim([0, 120])
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# Outer Key: (2021090900, 97)
# Inner Key: ((0, 40151.0), (13, 25511.0))

# %% [markdown]
# ### Save Sequence Arrays As Binary Files

# %%
import numpy as np

np.save("../data/trajectories.npy", [o_player_sequences, d_player_sequences])
np.save("../data/o_player_sequences_id.npy", o_player_sequences_id)

#array1, array2 = np.load("trajectories.npy")
# Out:
# C:\Users\Alejo\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\numpy\lib\npyio.py:501: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   arr = np.asanyarray(arr)

# %%
# %pip install json
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: C:\Users\Alejo\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import json

player_pairs_upload = {str(key): value for key, value in player_pairs.items()}

with open('../data/player_pairs.json', 'w') as f:
    json.dump(player_pairs_upload, f)


player_pair_ids_upload = {str(key): value for key, value in player_pair_ids.items()}

with open('../data/player_pair_ids.json', 'w') as f:
    json.dump(player_pair_ids_upload, f)

# %%
game_data.to_csv("../data/all_games.csv",index=False)
play_data.to_csv("../data/all_plays.csv",index=False)
player_data.to_csv("../data/all_players.csv",index=False)

# %% [markdown]
# - Flip order of pair detection/orientation (COMPLETE)
# - Example sequences to test LSTM framework (with/without padding as well) (COMPLETE)
# - Change metric for pair detection and rank the pairs by the metric in a table, select the top 100 and graph, and use these to train the model if they are feasible (This will ensure the quality of pairing) (IN PROGRESS)
# - Use plotly or a plotting library for first attempt at plotting
